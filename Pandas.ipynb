# %% [markdown]
# # Pandas

# %% [markdown]
# ![pandasimage](images/pandas.png)

# %% [markdown]
# ### Core Data Structures:
#
# Series: One-dimensional labeled array (like a column in Excel).
#
# DataFrame: Two-dimensional labeled data structure (like a table/spreadsheet).

# %% [markdown]
# ### => Handling Missing Data
# -- isna(), notna(), fillna(), dropna()
# ### => Powerful Data Indexing & Slicing
# -- .loc[] for label-based indexing | .iloc[] for integer-based indexing
# ### => Read/Write from Many Sources
# -- read_csv(), to_csv() | read_excel(), to_excel() | read_sql() | read_json()
# ### => Data Aggregation & Grouping
# -- df.groupby('column').sum() | df.pivot_table()
# ### => Merging and Joining
# -- merge() | concat() | join()
# ### => Data Cleaning & Transformation
# -- df.rename() | df.astype() | df.apply(), df.map() | df.replace()
# ### => Built-in Time Series Support
# -- pd.to_datetime() | df.resample('M')
# ### => Highly Optimized & Fast
# ### => Built on top of NumPy, so operations are vectorized and fast.
# ### => Works great with matplotlib and seaborn
# ### => Name "Pandas" is derived from "Panel Data"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series in pandas
#
# - its a one dimension labelled array

# %%
s1 = pd.Series([10, 20, 30, 40, 50, 60])
print(s1)
print(type(s1))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
s1 = pd.Series([10, 20, 30, 40, 50, 60])
print(s1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
s2 = pd.Series([10, 20, 30, 40, 50, 60], index=['a', 'b', 'c', 'd', 'e', 'f'], name="scores")
print(s2)

# When converting to DataFrame
# df = s2.to_frame()
# When merging Series or using DataFrames together — name becomes the column name.
# s2.name = "marks" # in case we want to change the name of the series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# Name: scores, dtype: int64

# %%
# create series from dict

data = {'a' : 10, 'b' : 20, 'c' : 30, 'd' : 40}
s3 = pd.Series(data, name = "marks")
print(s3)
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: marks, dtype: int64

# %%
# create series from dict

data = {'a' : 10, 'b' : "20", 'c' : 1.11, 'd' : True}
s4 = pd.Series(data)
print(s4)
# Out:
# a      10
# b      20
# c    1.11
# d    True
# dtype: object

# %%
# create series from dict

data = {'a' : 10, 'b' : "20", 1 : 1.11, 2 : True}
s5 = pd.Series(data)
print(s5)
# Out:
# a      10
# b      20
# 1    1.11
# 2    True
# dtype: object

# %%
# create series from np.array

np_array = np.array([10, 20, 30, 40, 50, 60])
s6 = pd.Series(np_array)
print(s6)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
# create series from dict

data = {'a' : 10, 'b' : 20, 'c' : 30, 'd' : 40}
s7 = pd.Series(data, name='scores')
print(s7)
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: scores, dtype: int64

# %%
print(s7.index) # it is of type object - pandas series indexes
print(s7.values) # it is of type numpy array
print(type(s7.values))
print(s7.dtypes) # gives the type of content in the series
print(s7.name)
print(s7.shape)
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')
# [10 20 30 40]
# <class 'numpy.ndarray'>
# int64
# scores
# (4,)

# %% [markdown]
# # Series indexing and slicing

# %%
print(s7, end = "\n\n")
print(s7.values[0]) # positional index
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: scores, dtype: int64
#
# 10

# %%
s7 = pd.Series([10, 20, 30])
print(s7.loc[0])
print(s7.loc[[0,1]])
print("=" * 50)

s7 = pd.Series([10, 20, 30], index=['a','b','c'])
# print(s7.loc[0]) # this will throw an error as indexes are changed
print(s7.loc['a']) # indexing
print(s7.loc[['a', 'b']])
print("=" * 50)

s7 = pd.Series([10, 20, 30], index=['a','b','c'])
print(s7.iloc[0]) # Positional indexing
print(s7.iloc[[0, 1]])
print(s7.iloc[0:2]) # Positional indexing (exclusive)
print("=" * 50)
# Out:
# 10
# 0    10
# 1    20
# dtype: int64
# ==================================================
# 10
# a    10
# b    20
# dtype: int64
# ==================================================
# 10
# a    10
# b    20
# dtype: int64
# a    10
# b    20
# dtype: int64
# ==================================================

# %%
data = {'a' : 10, 'b' : 20, 'c' : 30, 'd' : 40, 0 : 100, 1 : 101, 2 : 400, 6:700}
s9 = pd.Series(data, name='scores')
print(s9)
# Out:
# a     10
# b     20
# c     30
# d     40
# 0    100
# 1    101
# 2    400
# 6    700
# Name: scores, dtype: int64

# %%
s9.loc[0:2] # inclusive
# Out:
# 0    100
# 1    101
# 2    400
# Name: scores, dtype: int64

# %%
# Loc is Label-based indexing (Index labels), Slices are inclusive
# iloc is Integer-based indexing (Positions), Slices are exclusive of end

# Slicing
# - loc [start, end] : end is inclusive
# - iloc [start, end]  :end is exclusive

# %% [markdown]
# # DataFrame

# %%
data = {
    'Name' : ['Ananth', 'Pushpak', 'Nikhil'],
    'Age' : [24, 26, 28],
    'City' : ['Bengaluru', 'Hyderabad', 'Delhi']
}
# a dict with string as keys and list as values

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age       City
# 0   Ananth   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# 2   Nikhil   28      Delhi

# %%
data_1 = [
    {'Name' : 'Ananth', 'Age':'24', 'City':'Bengaluru'},
    {'Name' : 'Pushpak', 'Age':'26', 'City':'Hyderabad'},
    {'Name' : 'Nikhil', 'Age':'28', 'City':'Delhi'}
]

# a list contaning dicts

df_1 = pd.DataFrame(data_1)
print(df_1)
# Out:
#       Name Age       City
# 0   Ananth  24  Bengaluru
# 1  Pushpak  26  Hyderabad
# 2   Nikhil  28      Delhi

# %%
arr_data = np.array([[1,2],[3,4], [5,6]])
# a 2D numpy array
df_2 = pd.DataFrame(arr_data)
print(df_2)
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
df_2 = pd.DataFrame(arr_data, columns=['A', 'B']) # changing the column name
print(df_2)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6

# %% [markdown]
# # Accessing the values

# %%
data = {
    'Name' : ['Ananth', 'Pushpak', 'Nikhil'],
    'Age' : [24, 26, 28],
    'City' : ['Bengaluru', 'Hyderabad', 'Delhi']
}

df_4 = pd.DataFrame(data)
print(df)
print(type(df_4))
# Out:
#       Name  Age       City
# 0   Ananth   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# 2   Nikhil   28      Delhi
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df_4['Name'])
print("="*40)
print(df_4['Name'][[0,1]])
print("="*40)
print(df_4[['Name', 'Age']])
print("="*40)
print(df.loc[0])
print("="*40)
print(df.loc[0:1]) # Inclusive
print("="*40)
print(df.iloc[0])
print("="*40)
print(df.iloc[0:1]) # Exclusive
# Out:
# 0     Ananth
# 1    Pushpak
# 2     Nikhil
# Name: Name, dtype: object
# ========================================
# 0     Ananth
# 1    Pushpak
# Name: Name, dtype: object
# ========================================
#       Name  Age
# 0   Ananth   24
# 1  Pushpak   26
# 2   Nikhil   28
# ========================================
# Name       Ananth
# Age            24
# City    Bengaluru
# Name: 0, dtype: object
# ========================================
#       Name  Age       City
# 0   Ananth   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# ========================================
# Name       Ananth
# Age            24
# City    Bengaluru
# Name: 0, dtype: object
# ========================================
#      Name  Age       City
# 0  Ananth   24  Bengaluru

# %% [markdown]
# # Working with real dataset

# %%
# https://github.com/datasciencedojo/datasets
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

# https://github.com/mwaskom/seaborn-data/tree/master

iris_dataset_github_url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/refs/heads/master/iris.csv"

# kaggle
kaggle_link = "https://www.kaggle.com/datasets/yasserh/titanic-dataset/data"

# %%
df = pd.read_csv(titanic_dataset_github_url) # raw data

# %% [markdown]
# ### iteration in pandas
# - also done in mid. (we can pass iterrows and itertuples for now)

# %%
for index, row in df.iterrows():
    print(f"{index} name : {row.Name}")
# Out:
# 0 name : Braund, Mr. Owen Harris
# 1 name : Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# 2 name : Heikkinen, Miss. Laina
# 3 name : Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4 name : Allen, Mr. William Henry
# 5 name : Moran, Mr. James
# 6 name : McCarthy, Mr. Timothy J
# 7 name : Palsson, Master. Gosta Leonard
# 8 name : Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9 name : Nasser, Mrs. Nicholas (Adele Achem)
# 10 name : Sandstrom, Miss. Marguerite Rut
# 11 name : Bonnell, Miss. Elizabeth
# 12 name : Saundercock, Mr. William Henry
# 13 name : Andersson, Mr. Anders Johan
# 14 name : Vestrom, Miss. Hulda Amanda Adolfina
# 15 name : Hewlett, Mrs. (Mary D Kingcome)
# 16 name : Rice, Master. Eugene
# 17 name : Williams, Mr. Charles Eugene
# 18 name : Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)
# 19 name : Masselmani, Mrs. Fatima
# 20 name : Fynney, Mr. Joseph J
# 21 name : Beesley, Mr. Lawrence
# 22 name : McGowan, Miss. Anna "Annie"
# 23 name : Sloper, Mr. William Thompson
# 24 name : Palsson, Miss. Torborg Danira
# 25 name : Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)
# 26 name : Emir, Mr. Farred Chehab
# 27 name : Fortune, Mr. Charles Alexander
# 28 name : O'Dwyer, Miss. Ellen "Nellie"
# 29 name : Todoroff, Mr. Lalio
# 30 name : Uruchurtu, Don. Manuel E
# 31 name : Spencer, Mrs. William Augustus (Marie Eugenie)
# 32 name : Glynn, Miss. Mary Agatha
# 33 name : Wheadon, Mr. Edward H
# 34 name : Meyer, Mr. Edgar Joseph
# 35 name : Holverson, Mr. Alexander Oskar
# 36 name : Mamee, Mr. Hanna
# 37 name : Cann, Mr. Ernest Charles
# 38 name : Vander Planke, Miss. Augusta Maria
# 39 name : Nicola-Yarred, Miss. Jamila
# 40 name : Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 41 name : Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)
# 42 name : Kraeff, Mr. Theodor
# 43 name : Laroche, Miss. Simonne Marie Anne Andree
# 44 name : Devaney, Miss. Margaret Delia
# 45 name : Rogers, Mr. William John
# 46 name : Lennon, Mr. Denis
# 47 name : O'Driscoll, Miss. Bridget
# 48 name : Samaan, Mr. Youssef
# 49 name : Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# 50 name : Panula, Master. Juha Niilo
# 51 name : Nosworthy, Mr. Richard Cater
# 52 name : Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 53 name : Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)
# 54 name : Ostby, Mr. Engelhart Cornelius
# 55 name : Woolner, Mr. Hugh
# 56 name : Rugg, Miss. Emily
# 57 name : Novel, Mr. Mansouer
# 58 name : West, Miss. Constance Mirium
# 59 name : Goodwin, Master. William Frederick
# 60 name : Sirayanian, Mr. Orsen
# 61 name : Icard, Miss. Amelie
# 62 name : Harris, Mr. Henry Birkhardt
# 63 name : Skoog, Master. Harald
# 64 name : Stewart, Mr. Albert A
# 65 name : Moubarek, Master. Gerios
# 66 name : Nye, Mrs. (Elizabeth Ramell)
# 67 name : Crease, Mr. Ernest James
# 68 name : Andersson, Miss. Erna Alexandra
# 69 name : Kink, Mr. Vincenz
# 70 name : Jenkin, Mr. Stephen Curnow
# 71 name : Goodwin, Miss. Lillian Amy
# 72 name : Hood, Mr. Ambrose Jr
# 73 name : Chronopoulos, Mr. Apostolos
# 74 name : Bing, Mr. Lee
# 75 name : Moen, Mr. Sigurd Hansen
# 76 name : Staneff, Mr. Ivan
# 77 name : Moutal, Mr. Rahamin Haim
# 78 name : Caldwell, Master. Alden Gates
# 79 name : Dowdell, Miss. Elizabeth
# 80 name : Waelens, Mr. Achille
# 81 name : Sheerlinck, Mr. Jan Baptist
# 82 name : McDermott, Miss. Brigdet Delia
# 83 name : Carrau, Mr. Francisco M
# 84 name : Ilett, Miss. Bertha
# 85 name : Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)
# 86 name : Ford, Mr. William Neal
# 87 name : Slocovski, Mr. Selman Francis
# 88 name : Fortune, Miss. Mabel Helen
# 89 name : Celotti, Mr. Francesco
# 90 name : Christmann, Mr. Emil
# 91 name : Andreasson, Mr. Paul Edvin
# 92 name : Chaffee, Mr. Herbert Fuller
# 93 name : Dean, Mr. Bertram Frank
# 94 name : Coxon, Mr. Daniel
# 95 name : Shorney, Mr. Charles Joseph
# 96 name : Goldschmidt, Mr. George B
# 97 name : Greenfield, Mr. William Bertram
# 98 name : Doling, Mrs. John T (Ada Julia Bone)
# 99 name : Kantor, Mr. Sinai
# 100 name : Petranec, Miss. Matilda
# 101 name : Petroff, Mr. Pastcho ("Pentcho")
# 102 name : White, Mr. Richard Frasar
# 103 name : Johansson, Mr. Gustaf Joel
# 104 name : Gustafsson, Mr. Anders Vilhelm
# 105 name : Mionoff, Mr. Stoytcho
# 106 name : Salkjelsvik, Miss. Anna Kristine
# 107 name : Moss, Mr. Albert Johan
# 108 name : Rekic, Mr. Tido
# 109 name : Moran, Miss. Bertha
# 110 name : Porter, Mr. Walter Chamberlain
# 111 name : Zabour, Miss. Hileni
# 112 name : Barton, Mr. David John
# 113 name : Jussila, Miss. Katriina
# 114 name : Attalah, Miss. Malake
# 115 name : Pekoniemi, Mr. Edvard
# 116 name : Connors, Mr. Patrick
# 117 name : Turpin, Mr. William John Robert
# 118 name : Baxter, Mr. Quigg Edmond
# 119 name : Andersson, Miss. Ellis Anna Maria
# 120 name : Hickman, Mr. Stanley George
# 121 name : Moore, Mr. Leonard Charles
# 122 name : Nasser, Mr. Nicholas
# 123 name : Webber, Miss. Susan
# 124 name : White, Mr. Percival Wayland
# 125 name : Nicola-Yarred, Master. Elias
# 126 name : McMahon, Mr. Martin
# 127 name : Madsen, Mr. Fridtjof Arne
# 128 name : Peter, Miss. Anna
# 129 name : Ekstrom, Mr. Johan
# 130 name : Drazenoic, Mr. Jozef
# 131 name : Coelho, Mr. Domingos Fernandeo
# 132 name : Robins, Mrs. Alexander A (Grace Charity Laury)
# 133 name : Weisz, Mrs. Leopold (Mathilde Francoise Pede)
# 134 name : Sobey, Mr. Samuel James Hayden
# 135 name : Richard, Mr. Emile
# 136 name : Newsom, Miss. Helen Monypeny
# 137 name : Futrelle, Mr. Jacques Heath
# 138 name : Osen, Mr. Olaf Elon
# 139 name : Giglio, Mr. Victor
# 140 name : Boulos, Mrs. Joseph (Sultana)
# 141 name : Nysten, Miss. Anna Sofia
# 142 name : Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)
# 143 name : Burke, Mr. Jeremiah
# 144 name : Andrew, Mr. Edgardo Samuel
# 145 name : Nicholls, Mr. Joseph Charles
# 146 name : Andersson, Mr. August Edvard ("Wennerstrom")
# 147 name : Ford, Miss. Robina Maggie "Ruby"
# 148 name : Navratil, Mr. Michel ("Louis M Hoffman")
# 149 name : Byles, Rev. Thomas Roussel Davids
# 150 name : Bateman, Rev. Robert James
# 151 name : Pears, Mrs. Thomas (Edith Wearne)
# 152 name : Meo, Mr. Alfonzo
# 153 name : van Billiard, Mr. Austin Blyler
# 154 name : Olsen, Mr. Ole Martin
# 155 name : Williams, Mr. Charles Duane
# 156 name : Gilnagh, Miss. Katherine "Katie"
# 157 name : Corn, Mr. Harry
# 158 name : Smiljanic, Mr. Mile
# 159 name : Sage, Master. Thomas Henry
# 160 name : Cribb, Mr. John Hatfield
# 161 name : Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)
# 162 name : Bengtsson, Mr. John Viktor
# 163 name : Calic, Mr. Jovo
# 164 name : Panula, Master. Eino Viljami
# 165 name : Goldsmith, Master. Frank John William "Frankie"
# 166 name : Chibnall, Mrs. (Edith Martha Bowerman)
# 167 name : Skoog, Mrs. William (Anna Bernhardina Karlsson)
# 168 name : Baumann, Mr. John D
# 169 name : Ling, Mr. Lee
# 170 name : Van der hoef, Mr. Wyckoff
# 171 name : Rice, Master. Arthur
# 172 name : Johnson, Miss. Eleanor Ileen
# 173 name : Sivola, Mr. Antti Wilhelm
# 174 name : Smith, Mr. James Clinch
# 175 name : Klasen, Mr. Klas Albin
# 176 name : Lefebre, Master. Henry Forbes
# 177 name : Isham, Miss. Ann Elizabeth
# 178 name : Hale, Mr. Reginald
# 179 name : Leonard, Mr. Lionel
# 180 name : Sage, Miss. Constance Gladys
# 181 name : Pernot, Mr. Rene
# 182 name : Asplund, Master. Clarence Gustaf Hugo
# 183 name : Becker, Master. Richard F
# 184 name : Kink-Heilmann, Miss. Luise Gretchen
# 185 name : Rood, Mr. Hugh Roscoe
# 186 name : O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)
# 187 name : Romaine, Mr. Charles Hallace ("Mr C Rolmane")
# 188 name : Bourke, Mr. John
# 189 name : Turcin, Mr. Stjepan
# 190 name : Pinsky, Mrs. (Rosa)
# 191 name : Carbines, Mr. William
# 192 name : Andersen-Jensen, Miss. Carla Christine Nielsine
# 193 name : Navratil, Master. Michel M
# 194 name : Brown, Mrs. James Joseph (Margaret Tobin)
# 195 name : Lurette, Miss. Elise
# 196 name : Mernagh, Mr. Robert
# 197 name : Olsen, Mr. Karl Siegwart Andreas
# 198 name : Madigan, Miss. Margaret "Maggie"
# 199 name : Yrois, Miss. Henriette ("Mrs Harbeck")
# 200 name : Vande Walle, Mr. Nestor Cyriel
# 201 name : Sage, Mr. Frederick
# 202 name : Johanson, Mr. Jakob Alfred
# 203 name : Youseff, Mr. Gerious
# 204 name : Cohen, Mr. Gurshon "Gus"
# 205 name : Strom, Miss. Telma Matilda
# 206 name : Backstrom, Mr. Karl Alfred
# 207 name : Albimona, Mr. Nassef Cassem
# 208 name : Carr, Miss. Helen "Ellen"
# 209 name : Blank, Mr. Henry
# 210 name : Ali, Mr. Ahmed
# 211 name : Cameron, Miss. Clear Annie
# 212 name : Perkin, Mr. John Henry
# 213 name : Givard, Mr. Hans Kristensen
# 214 name : Kiernan, Mr. Philip
# 215 name : Newell, Miss. Madeleine
# 216 name : Honkanen, Miss. Eliina
# 217 name : Jacobsohn, Mr. Sidney Samuel
# 218 name : Bazzani, Miss. Albina
# 219 name : Harris, Mr. Walter
# 220 name : Sunderland, Mr. Victor Francis
# 221 name : Bracken, Mr. James H
# 222 name : Green, Mr. George Henry
# 223 name : Nenkoff, Mr. Christo
# 224 name : Hoyt, Mr. Frederick Maxfield
# 225 name : Berglund, Mr. Karl Ivar Sven
# 226 name : Mellors, Mr. William John
# 227 name : Lovell, Mr. John Hall ("Henry")
# 228 name : Fahlstrom, Mr. Arne Jonas
# 229 name : Lefebre, Miss. Mathilde
# 230 name : Harris, Mrs. Henry Birkhardt (Irene Wallach)
# 231 name : Larsson, Mr. Bengt Edvin
# 232 name : Sjostedt, Mr. Ernst Adolf
# 233 name : Asplund, Miss. Lillian Gertrud
# 234 name : Leyson, Mr. Robert William Norman
# 235 name : Harknett, Miss. Alice Phoebe
# 236 name : Hold, Mr. Stephen
# 237 name : Collyer, Miss. Marjorie "Lottie"
# 238 name : Pengelly, Mr. Frederick William
# 239 name : Hunt, Mr. George Henry
# 240 name : Zabour, Miss. Thamine
# 241 name : Murphy, Miss. Katherine "Kate"
# 242 name : Coleridge, Mr. Reginald Charles
# 243 name : Maenpaa, Mr. Matti Alexanteri
# 244 name : Attalah, Mr. Sleiman
# 245 name : Minahan, Dr. William Edward
# 246 name : Lindahl, Miss. Agda Thorilda Viktoria
# 247 name : Hamalainen, Mrs. William (Anna)
# 248 name : Beckwith, Mr. Richard Leonard
# 249 name : Carter, Rev. Ernest Courtenay
# 250 name : Reed, Mr. James George
# 251 name : Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 252 name : Stead, Mr. William Thomas
# 253 name : Lobb, Mr. William Arthur
# 254 name : Rosblom, Mrs. Viktor (Helena Wilhelmina)
# 255 name : Touma, Mrs. Darwis (Hanne Youssef Razi)
# 256 name : Thorne, Mrs. Gertrude Maybelle
# 257 name : Cherry, Miss. Gladys
# 258 name : Ward, Miss. Anna
# 259 name : Parrish, Mrs. (Lutie Davis)
# 260 name : Smith, Mr. Thomas
# 261 name : Asplund, Master. Edvin Rojj Felix
# 262 name : Taussig, Mr. Emil
# 263 name : Harrison, Mr. William
# 264 name : Henry, Miss. Delia
# 265 name : Reeves, Mr. David
# 266 name : Panula, Mr. Ernesti Arvid
# 267 name : Persson, Mr. Ernst Ulrik
# 268 name : Graham, Mrs. William Thompson (Edith Junkins)
# 269 name : Bissette, Miss. Amelia
# 270 name : Cairns, Mr. Alexander
# 271 name : Tornquist, Mr. William Henry
# 272 name : Mellinger, Mrs. (Elizabeth Anne Maidment)
# 273 name : Natsch, Mr. Charles H
# 274 name : Healy, Miss. Hanora "Nora"
# 275 name : Andrews, Miss. Kornelia Theodosia
# 276 name : Lindblom, Miss. Augusta Charlotta
# 277 name : Parkes, Mr. Francis "Frank"
# 278 name : Rice, Master. Eric
# 279 name : Abbott, Mrs. Stanton (Rosa Hunt)
# 280 name : Duane, Mr. Frank
# 281 name : Olsson, Mr. Nils Johan Goransson
# 282 name : de Pelsmaeker, Mr. Alfons
# 283 name : Dorking, Mr. Edward Arthur
# 284 name : Smith, Mr. Richard William
# 285 name : Stankovic, Mr. Ivan
# 286 name : de Mulder, Mr. Theodore
# 287 name : Naidenoff, Mr. Penko
# 288 name : Hosono, Mr. Masabumi
# 289 name : Connolly, Miss. Kate
# 290 name : Barber, Miss. Ellen "Nellie"
# 291 name : Bishop, Mrs. Dickinson H (Helen Walton)
# 292 name : Levy, Mr. Rene Jacques
# 293 name : Haas, Miss. Aloisia
# 294 name : Mineff, Mr. Ivan
# 295 name : Lewy, Mr. Ervin G
# 296 name : Hanna, Mr. Mansour
# 297 name : Allison, Miss. Helen Loraine
# 298 name : Saalfeld, Mr. Adolphe
# 299 name : Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 300 name : Kelly, Miss. Anna Katherine "Annie Kate"
# 301 name : McCoy, Mr. Bernard
# 302 name : Johnson, Mr. William Cahoone Jr
# 303 name : Keane, Miss. Nora A
# 304 name : Williams, Mr. Howard Hugh "Harry"
# 305 name : Allison, Master. Hudson Trevor
# 306 name : Fleming, Miss. Margaret
# 307 name : Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)
# 308 name : Abelson, Mr. Samuel
# 309 name : Francatelli, Miss. Laura Mabel
# 310 name : Hays, Miss. Margaret Bechstein
# 311 name : Ryerson, Miss. Emily Borie
# 312 name : Lahtinen, Mrs. William (Anna Sylfven)
# 313 name : Hendekovic, Mr. Ignjac
# 314 name : Hart, Mr. Benjamin
# 315 name : Nilsson, Miss. Helmina Josefina
# 316 name : Kantor, Mrs. Sinai (Miriam Sternin)
# 317 name : Moraweck, Dr. Ernest
# 318 name : Wick, Miss. Mary Natalie
# 319 name : Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)
# 320 name : Dennis, Mr. Samuel
# 321 name : Danoff, Mr. Yoto
# 322 name : Slayter, Miss. Hilda Mary
# 323 name : Caldwell, Mrs. Albert Francis (Sylvia Mae Harbaugh)
# 324 name : Sage, Mr. George John Jr
# 325 name : Young, Miss. Marie Grice
# 326 name : Nysveen, Mr. Johan Hansen
# 327 name : Ball, Mrs. (Ada E Hall)
# 328 name : Goldsmith, Mrs. Frank John (Emily Alice Brown)
# 329 name : Hippach, Miss. Jean Gertrude
# 330 name : McCoy, Miss. Agnes
# 331 name : Partner, Mr. Austen
# 332 name : Graham, Mr. George Edward
# 333 name : Vander Planke, Mr. Leo Edmondus
# 334 name : Frauenthal, Mrs. Henry William (Clara Heinsheimer)
# 335 name : Denkoff, Mr. Mitto
# 336 name : Pears, Mr. Thomas Clinton
# 337 name : Burns, Miss. Elizabeth Margaret
# 338 name : Dahl, Mr. Karl Edwart
# 339 name : Blackwell, Mr. Stephen Weart
# 340 name : Navratil, Master. Edmond Roger
# 341 name : Fortune, Miss. Alice Elizabeth
# 342 name : Collander, Mr. Erik Gustaf
# 343 name : Sedgwick, Mr. Charles Frederick Waddington
# 344 name : Fox, Mr. Stanley Hubert
# 345 name : Brown, Miss. Amelia "Mildred"
# 346 name : Smith, Miss. Marion Elsie
# 347 name : Davison, Mrs. Thomas Henry (Mary E Finck)
# 348 name : Coutts, Master. William Loch "William"
# 349 name : Dimic, Mr. Jovan
# 350 name : Odahl, Mr. Nils Martin
# 351 name : Williams-Lambert, Mr. Fletcher Fellows
# 352 name : Elias, Mr. Tannous
# 353 name : Arnold-Franchi, Mr. Josef
# 354 name : Yousif, Mr. Wazli
# 355 name : Vanden Steen, Mr. Leo Peter
# 356 name : Bowerman, Miss. Elsie Edith
# 357 name : Funk, Miss. Annie Clemmer
# 358 name : McGovern, Miss. Mary
# 359 name : Mockler, Miss. Helen Mary "Ellie"
# 360 name : Skoog, Mr. Wilhelm
# 361 name : del Carlo, Mr. Sebastiano
# 362 name : Barbara, Mrs. (Catherine David)
# 363 name : Asim, Mr. Adola
# 364 name : O'Brien, Mr. Thomas
# 365 name : Adahl, Mr. Mauritz Nils Martin
# 366 name : Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 367 name : Moussa, Mrs. (Mantoura Boulos)
# 368 name : Jermyn, Miss. Annie
# 369 name : Aubart, Mme. Leontine Pauline
# 370 name : Harder, Mr. George Achilles
# 371 name : Wiklund, Mr. Jakob Alfred
# 372 name : Beavan, Mr. William Thomas
# 373 name : Ringhini, Mr. Sante
# 374 name : Palsson, Miss. Stina Viola
# 375 name : Meyer, Mrs. Edgar Joseph (Leila Saks)
# 376 name : Landergren, Miss. Aurora Adelia
# 377 name : Widener, Mr. Harry Elkins
# 378 name : Betros, Mr. Tannous
# 379 name : Gustafsson, Mr. Karl Gideon
# 380 name : Bidois, Miss. Rosalie
# 381 name : Nakid, Miss. Maria ("Mary")
# 382 name : Tikkanen, Mr. Juho
# 383 name : Holverson, Mrs. Alexander Oskar (Mary Aline Towner)
# 384 name : Plotcharsky, Mr. Vasil
# 385 name : Davies, Mr. Charles Henry
# 386 name : Goodwin, Master. Sidney Leonard
# 387 name : Buss, Miss. Kate
# 388 name : Sadlier, Mr. Matthew
# 389 name : Lehmann, Miss. Bertha
# 390 name : Carter, Mr. William Ernest
# 391 name : Jansson, Mr. Carl Olof
# 392 name : Gustafsson, Mr. Johan Birger
# 393 name : Newell, Miss. Marjorie
# 394 name : Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)
# 395 name : Johansson, Mr. Erik
# 396 name : Olsson, Miss. Elina
# 397 name : McKane, Mr. Peter David
# 398 name : Pain, Dr. Alfred
# 399 name : Trout, Mrs. William H (Jessie L)
# 400 name : Niskanen, Mr. Juha
# 401 name : Adams, Mr. John
# 402 name : Jussila, Miss. Mari Aina
# 403 name : Hakkarainen, Mr. Pekka Pietari
# 404 name : Oreskovic, Miss. Marija
# 405 name : Gale, Mr. Shadrach
# 406 name : Widegren, Mr. Carl/Charles Peter
# 407 name : Richards, Master. William Rowe
# 408 name : Birkeland, Mr. Hans Martin Monsen
# 409 name : Lefebre, Miss. Ida
# 410 name : Sdycoff, Mr. Todor
# 411 name : Hart, Mr. Henry
# 412 name : Minahan, Miss. Daisy E
# 413 name : Cunningham, Mr. Alfred Fleming
# 414 name : Sundman, Mr. Johan Julian
# 415 name : Meek, Mrs. Thomas (Annie Louise Rowley)
# 416 name : Drew, Mrs. James Vivian (Lulu Thorne Christian)
# 417 name : Silven, Miss. Lyyli Karoliina
# 418 name : Matthews, Mr. William John
# 419 name : Van Impe, Miss. Catharina
# 420 name : Gheorgheff, Mr. Stanio
# 421 name : Charters, Mr. David
# 422 name : Zimmerman, Mr. Leo
# 423 name : Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria Brogren)
# 424 name : Rosblom, Mr. Viktor Richard
# 425 name : Wiseman, Mr. Phillippe
# 426 name : Clarke, Mrs. Charles V (Ada Maria Winfield)
# 427 name : Phillips, Miss. Kate Florence ("Mrs Kate Louise Phillips Marshall")
# 428 name : Flynn, Mr. James
# 429 name : Pickard, Mr. Berk (Berk Trembisky)
# 430 name : Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 431 name : Thorneycroft, Mrs. Percival (Florence Kate White)
# 432 name : Louch, Mrs. Charles Alexander (Alice Adelaide Slow)
# 433 name : Kallio, Mr. Nikolai Erland
# 434 name : Silvey, Mr. William Baird
# 435 name : Carter, Miss. Lucile Polk
# 436 name : Ford, Miss. Doolina Margaret "Daisy"
# 437 name : Richards, Mrs. Sidney (Emily Hocking)
# 438 name : Fortune, Mr. Mark
# 439 name : Kvillner, Mr. Johan Henrik Johannesson
# 440 name : Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# 510 name : Daly, Mr. Eugene Patrick
# 511 name : Webber, Mr. James
# 512 name : McGough, Mr. James Robert
# 513 name : Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# 514 name : Coleff, Mr. Satio
# 515 name : Walker, Mr. William Anderson
# 516 name : Lemore, Mrs. (Amelia Milley)
# 517 name : Ryan, Mr. Patrick
# 518 name : Angle, Mrs. William A (Florence "Mary" Agnes Hughes)
# 519 name : Pavlovic, Mr. Stefo
# 520 name : Perreault, Miss. Anne
# 521 name : Vovk, Mr. Janko
# 522 name : Lahoud, Mr. Sarkis
# 523 name : Hippach, Mrs. Louis Albert (Ida Sophia Fischer)
# 524 name : Kassem, Mr. Fared
# 525 name : Farrell, Mr. James
# 526 name : Ridsdale, Miss. Lucy
# 527 name : Farthing, Mr. John
# 528 name : Salonen, Mr. Johan Werner
# 529 name : Hocking, Mr. Richard George
# 530 name : Quick, Miss. Phyllis May
# 531 name : Toufik, Mr. Nakli
# 532 name : Elias, Mr. Joseph Jr
# 533 name : Peter, Mrs. Catherine (Catherine Rizk)
# 534 name : Cacic, Miss. Marija
# 535 name : Hart, Miss. Eva Miriam
# 536 name : Butt, Major. Archibald Willingham
# 537 name : LeRoy, Miss. Bertha
# 538 name : Risien, Mr. Samuel Beard
# 539 name : Frolicher, Miss. Hedwig Margaritha
# 540 name : Crosby, Miss. Harriet R
# 541 name : Andersson, Miss. Ingeborg Constanzia
# 542 name : Andersson, Miss. Sigrid Elisabeth
# 543 name : Beane, Mr. Edward
# 544 name : Douglas, Mr. Walter Donald
# 545 name : Nicholson, Mr. Arthur Ernest
# 546 name : Beane, Mrs. Edward (Ethel Clarke)
# 547 name : Padro y Manent, Mr. Julian
# 548 name : Goldsmith, Mr. Frank John
# 549 name : Davies, Master. John Morgan Jr
# 550 name : Thayer, Mr. John Borland Jr
# 551 name : Sharp, Mr. Percival James R
# 552 name : O'Brien, Mr. Timothy
# 553 name : Leeni, Mr. Fahim ("Philip Zenni")
# 554 name : Ohman, Miss. Velin
# 555 name : Wright, Mr. George
# 556 name : Duff Gordon, Lady. (Lucille Christiana Sutherland) ("Mrs Morgan")
# 557 name : Robbins, Mr. Victor
# 558 name : Taussig, Mrs. Emil (Tillie Mandelbaum)
# 559 name : de Messemaeker, Mrs. Guillaume Joseph (Emma)
# 560 name : Morrow, Mr. Thomas Rowan
# 561 name : Sivic, Mr. Husein
# 562 name : Norman, Mr. Robert Douglas
# 563 name : Simmons, Mr. John
# 564 name : Meanwell, Miss. (Marion Ogden)
# 565 name : Davies, Mr. Alfred J
# 566 name : Stoytcheff, Mr. Ilia
# 567 name : Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 568 name : Doharr, Mr. Tannous
# 569 name : Jonsson, Mr. Carl
# 570 name : Harris, Mr. George
# 571 name : Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 572 name : Flynn, Mr. John Irwin ("Irving")
# 573 name : Kelly, Miss. Mary
# 574 name : Rush, Mr. Alfred George John
# 575 name : Patchett, Mr. George
# 576 name : Garside, Miss. Ethel
# 577 name : Silvey, Mrs. William Baird (Alice Munger)
# 578 name : Caram, Mrs. Joseph (Maria Elias)
# 579 name : Jussila, Mr. Eiriik
# 580 name : Christy, Miss. Julie Rachel
# 581 name : Thayer, Mrs. John Borland (Marian Longstreth Morris)
# 582 name : Downton, Mr. William James
# 583 name : Ross, Mr. John Hugo
# 584 name : Paulner, Mr. Uscher
# 585 name : Taussig, Miss. Ruth
# 586 name : Jarvis, Mr. John Denzil
# 587 name : Frolicher-Stehli, Mr. Maxmillian
# 588 name : Gilinski, Mr. Eliezer
# 589 name : Murdlin, Mr. Joseph
# 590 name : Rintamaki, Mr. Matti
# 591 name : Stephenson, Mrs. Walter Bertram (Martha Eustis)
# 592 name : Elsbury, Mr. William James
# 593 name : Bourke, Miss. Mary
# 594 name : Chapman, Mr. John Henry
# 595 name : Van Impe, Mr. Jean Baptiste
# 596 name : Leitch, Miss. Jessie Wills
# 597 name : Johnson, Mr. Alfred
# 598 name : Boulos, Mr. Hanna
# 599 name : Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# 600 name : Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)
# 601 name : Slabenoff, Mr. Petco
# 602 name : Harrington, Mr. Charles H
# 603 name : Torber, Mr. Ernst William
# 604 name : Homer, Mr. Harry ("Mr E Haven")
# 605 name : Lindell, Mr. Edvard Bengtsson
# 606 name : Karaic, Mr. Milan
# 607 name : Daniel, Mr. Robert Williams
# 608 name : Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)
# 609 name : Shutes, Miss. Elizabeth W
# 610 name : Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)
# 611 name : Jardin, Mr. Jose Neto
# 612 name : Murphy, Miss. Margaret Jane
# 613 name : Horgan, Mr. John
# 614 name : Brocklebank, Mr. William Alfred
# 615 name : Herman, Miss. Alice
# 616 name : Danbom, Mr. Ernst Gilbert
# 617 name : Lobb, Mrs. William Arthur (Cordelia K Stanlick)
# 618 name : Becker, Miss. Marion Louise
# 619 name : Gavey, Mr. Lawrence
# 620 name : Yasbeck, Mr. Antoni
# 621 name : Kimball, Mr. Edwin Nelson Jr
# 622 name : Nakid, Mr. Sahid
# 623 name : Hansen, Mr. Henry Damsgaard
# 624 name : Bowen, Mr. David John "Dai"
# 625 name : Sutton, Mr. Frederick
# 626 name : Kirkland, Rev. Charles Leonard
# 627 name : Longley, Miss. Gretchen Fiske
# 628 name : Bostandyeff, Mr. Guentcho
# 629 name : O'Connell, Mr. Patrick D
# 630 name : Barkworth, Mr. Algernon Henry Wilson
# 631 name : Lundahl, Mr. Johan Svensson
# 632 name : Stahelin-Maeglin, Dr. Max
# 633 name : Parr, Mr. William Henry Marsh
# 634 name : Skoog, Miss. Mabel
# 635 name : Davis, Miss. Mary
# 636 name : Leinonen, Mr. Antti Gustaf
# 637 name : Collyer, Mr. Harvey
# 638 name : Panula, Mrs. Juha (Maria Emilia Ojala)
# 639 name : Thorneycroft, Mr. Percival
# 640 name : Jensen, Mr. Hans Peder
# 641 name : Sagesser, Mlle. Emma
# 642 name : Skoog, Miss. Margit Elizabeth
# 643 name : Foo, Mr. Choong
# 644 name : Baclini, Miss. Eugenie
# 645 name : Harper, Mr. Henry Sleeper
# 646 name : Cor, Mr. Liudevit
# 647 name : Simonius-Blumer, Col. Oberst Alfons
# 648 name : Willey, Mr. Edward
# 649 name : Stanley, Miss. Amy Zillah Elsie
# 650 name : Mitkoff, Mr. Mito
# 651 name : Doling, Miss. Elsie
# 652 name : Kalvik, Mr. Johannes Halvorsen
# 653 name : O'Leary, Miss. Hanora "Norah"
# 654 name : Hegarty, Miss. Hanora "Nora"
# 655 name : Hickman, Mr. Leonard Mark
# 656 name : Radeff, Mr. Alexander
# 657 name : Bourke, Mrs. John (Catherine)
# 658 name : Eitemiller, Mr. George Floyd
# 659 name : Newell, Mr. Arthur Webster
# 660 name : Frauenthal, Dr. Henry William
# 661 name : Badt, Mr. Mohamed
# 662 name : Colley, Mr. Edward Pomeroy
# 663 name : Coleff, Mr. Peju
# 664 name : Lindqvist, Mr. Eino William
# 665 name : Hickman, Mr. Lewis
# 666 name : Butler, Mr. Reginald Fenton
# 667 name : Rommetvedt, Mr. Knud Paust
# 668 name : Cook, Mr. Jacob
# 669 name : Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)
# 670 name : Brown, Mrs. Thomas William Solomon (Elizabeth Catherine Ford)
# 671 name : Davidson, Mr. Thornton
# 672 name : Mitchell, Mr. Henry Michael
# 673 name : Wilhelms, Mr. Charles
# 674 name : Watson, Mr. Ennis Hastings
# 675 name : Edvardsson, Mr. Gustaf Hjalmar
# 676 name : Sawyer, Mr. Frederick Charles
# 677 name : Turja, Miss. Anna Sofia
# 678 name : Goodwin, Mrs. Frederick (Augusta Tyler)
# 679 name : Cardeza, Mr. Thomas Drake Martinez
# 680 name : Peters, Miss. Katie
# 681 name : Hassab, Mr. Hammad
# 682 name : Olsvigen, Mr. Thor Anderson
# 683 name : Goodwin, Mr. Charles Edward
# 684 name : Brown, Mr. Thomas William Solomon
# 685 name : Laroche, Mr. Joseph Philippe Lemercier
# 686 name : Panula, Mr. Jaako Arnold
# 687 name : Dakic, Mr. Branko
# 688 name : Fischer, Mr. Eberhard Thelander
# 689 name : Madill, Miss. Georgette Alexandra
# 690 name : Dick, Mr. Albert Adrian
# 691 name : Karun, Miss. Manca
# 692 name : Lam, Mr. Ali
# 693 name : Saad, Mr. Khalil
# 694 name : Weir, Col. John
# 695 name : Chapman, Mr. Charles Henry
# 696 name : Kelly, Mr. James
# 697 name : Mullens, Miss. Katherine "Katie"
# 698 name : Thayer, Mr. John Borland
# 699 name : Humblen, Mr. Adolf Mathias Nicolai Olsen
# 700 name : Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 701 name : Silverthorne, Mr. Spencer Victor
# 702 name : Barbara, Miss. Saiide
# 703 name : Gallagher, Mr. Martin
# 704 name : Hansen, Mr. Henrik Juul
# 705 name : Morley, Mr. Henry Samuel ("Mr Henry Marshall")
# 706 name : Kelly, Mrs. Florence "Fannie"
# 707 name : Calderhead, Mr. Edward Pennington
# 708 name : Cleaver, Miss. Alice
# 709 name : Moubarek, Master. Halim Gonios ("William George")
# 710 name : Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 711 name : Klaber, Mr. Herman
# 712 name : Taylor, Mr. Elmer Zebley
# 713 name : Larsson, Mr. August Viktor
# 714 name : Greenberg, Mr. Samuel
# 715 name : Soholt, Mr. Peter Andreas Lauritz Andersen
# 716 name : Endres, Miss. Caroline Louise
# 717 name : Troutt, Miss. Edwina Celia "Winnie"
# 718 name : McEvoy, Mr. Michael
# 719 name : Johnson, Mr. Malkolm Joackim
# 720 name : Harper, Miss. Annie Jessie "Nina"
# 721 name : Jensen, Mr. Svend Lauritz
# 722 name : Gillespie, Mr. William Henry
# 723 name : Hodges, Mr. Henry Price
# 724 name : Chambers, Mr. Norman Campbell
# 725 name : Oreskovic, Mr. Luka
# 726 name : Renouf, Mrs. Peter Henry (Lillian Jefferys)
# 727 name : Mannion, Miss. Margareth
# 728 name : Bryhl, Mr. Kurt Arnold Gottfrid
# 729 name : Ilmakangas, Miss. Pieta Sofia
# 730 name : Allen, Miss. Elisabeth Walton
# 731 name : Hassan, Mr. Houssein G N
# 732 name : Knight, Mr. Robert J
# 733 name : Berriman, Mr. William John
# 734 name : Troupiansky, Mr. Moses Aaron
# 735 name : Williams, Mr. Leslie
# 736 name : Ford, Mrs. Edward (Margaret Ann Watson)
# 737 name : Lesurer, Mr. Gustave J
# 738 name : Ivanoff, Mr. Kanio
# 739 name : Nankoff, Mr. Minko
# 740 name : Hawksford, Mr. Walter James
# 741 name : Cavendish, Mr. Tyrell William
# 742 name : Ryerson, Miss. Susan Parker "Suzette"
# 743 name : McNamee, Mr. Neal
# 744 name : Stranden, Mr. Juho
# 745 name : Crosby, Capt. Edward Gifford
# 746 name : Abbott, Mr. Rossmore Edward
# 747 name : Sinkkonen, Miss. Anna
# 748 name : Marvin, Mr. Daniel Warner
# 749 name : Connaghton, Mr. Michael
# 750 name : Wells, Miss. Joan
# 751 name : Moor, Master. Meier
# 752 name : Vande Velde, Mr. Johannes Joseph
# 753 name : Jonkoff, Mr. Lalio
# 754 name : Herman, Mrs. Samuel (Jane Laver)
# 755 name : Hamalainen, Master. Viljo
# 756 name : Carlsson, Mr. August Sigfrid
# 757 name : Bailey, Mr. Percy Andrew
# 758 name : Theobald, Mr. Thomas Leonard
# 759 name : Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)
# 760 name : Garfirth, Mr. John
# 761 name : Nirva, Mr. Iisakki Antino Aijo
# 762 name : Barah, Mr. Hanna Assi
# 763 name : Carter, Mrs. William Ernest (Lucile Polk)
# 764 name : Eklund, Mr. Hans Linus
# 765 name : Hogeboom, Mrs. John C (Anna Andrews)
# 766 name : Brewe, Dr. Arthur Jackson
# 767 name : Mangan, Miss. Mary
# 768 name : Moran, Mr. Daniel J
# 769 name : Gronnestad, Mr. Daniel Danielsen
# 770 name : Lievens, Mr. Rene Aime
# 771 name : Jensen, Mr. Niels Peder
# 772 name : Mack, Mrs. (Mary)
# 773 name : Elias, Mr. Dibo
# 774 name : Hocking, Mrs. Elizabeth (Eliza Needs)
# 775 name : Myhrman, Mr. Pehr Fabian Oliver Malkolm
# 776 name : Tobin, Mr. Roger
# 777 name : Emanuel, Miss. Virginia Ethel
# 778 name : Kilgannon, Mr. Thomas J
# 779 name : Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)
# 780 name : Ayoub, Miss. Banoura
# 781 name : Dick, Mrs. Albert Adrian (Vera Gillespie)
# 782 name : Long, Mr. Milton Clyde
# 783 name : Johnston, Mr. Andrew G
# 784 name : Ali, Mr. William
# 785 name : Harmer, Mr. Abraham (David Lishin)
# 786 name : Sjoblom, Miss. Anna Sofia
# 787 name : Rice, Master. George Hugh
# 788 name : Dean, Master. Bertram Vere
# 789 name : Guggenheim, Mr. Benjamin
# 790 name : Keane, Mr. Andrew "Andy"
# 791 name : Gaskell, Mr. Alfred
# 792 name : Sage, Miss. Stella Anna
# 793 name : Hoyt, Mr. William Fisher
# 794 name : Dantcheff, Mr. Ristiu
# 795 name : Otter, Mr. Richard
# 796 name : Leader, Dr. Alice (Farnham)
# 797 name : Osman, Mrs. Mara
# 798 name : Ibrahim Shawah, Mr. Yousseff
# 799 name : Van Impe, Mrs. Jean Baptiste (Rosalie Paula Govaert)
# 800 name : Ponesell, Mr. Martin
# 801 name : Collyer, Mrs. Harvey (Charlotte Annie Tate)
# 802 name : Carter, Master. William Thornton II
# 803 name : Thomas, Master. Assad Alexander
# 804 name : Hedman, Mr. Oskar Arvid
# 805 name : Johansson, Mr. Karl Johan
# 806 name : Andrews, Mr. Thomas Jr
# 807 name : Pettersson, Miss. Ellen Natalia
# 808 name : Meyer, Mr. August
# 809 name : Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 810 name : Alexander, Mr. William
# 811 name : Lester, Mr. James
# 812 name : Slemen, Mr. Richard James
# 813 name : Andersson, Miss. Ebba Iris Alfrida
# 814 name : Tomlin, Mr. Ernest Portage
# 815 name : Fry, Mr. Richard
# 816 name : Heininen, Miss. Wendla Maria
# 817 name : Mallet, Mr. Albert
# 818 name : Holm, Mr. John Fredrik Alexander
# 819 name : Skoog, Master. Karl Thorsten
# 820 name : Hays, Mrs. Charles Melville (Clara Jennings Gregg)
# 821 name : Lulic, Mr. Nikola
# 822 name : Reuchlin, Jonkheer. John George
# 823 name : Moor, Mrs. (Beila)
# 824 name : Panula, Master. Urho Abraham
# 825 name : Flynn, Mr. John
# 826 name : Lam, Mr. Len
# 827 name : Mallet, Master. Andre
# 828 name : McCormack, Mr. Thomas Joseph
# 829 name : Stone, Mrs. George Nelson (Martha Evelyn)
# 830 name : Yasbeck, Mrs. Antoni (Selini Alexander)
# 831 name : Richards, Master. George Sibley
# 832 name : Saad, Mr. Amin
# 833 name : Augustsson, Mr. Albert
# 834 name : Allum, Mr. Owen George
# 835 name : Compton, Miss. Sara Rebecca
# 836 name : Pasic, Mr. Jakob
# 837 name : Sirota, Mr. Maurice
# 838 name : Chip, Mr. Chang
# 839 name : Marechal, Mr. Pierre
# 840 name : Alhomaki, Mr. Ilmari Rudolf
# 841 name : Mudd, Mr. Thomas Charles
# 842 name : Serepeca, Miss. Augusta
# 843 name : Lemberopolous, Mr. Peter L
# 844 name : Culumovic, Mr. Jeso
# 845 name : Abbing, Mr. Anthony
# 846 name : Sage, Mr. Douglas Bullen
# 847 name : Markoff, Mr. Marin
# 848 name : Harper, Rev. John
# 849 name : Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 850 name : Andersson, Master. Sigvard Harald Elias
# 851 name : Svensson, Mr. Johan
# 852 name : Boulos, Miss. Nourelain
# 853 name : Lines, Miss. Mary Conover
# 854 name : Carter, Mrs. Ernest Courtenay (Lilian Hughes)
# 855 name : Aks, Mrs. Sam (Leah Rosen)
# 856 name : Wick, Mrs. George Dennick (Mary Hitchcock)
# 857 name : Daly, Mr. Peter Denis
# 858 name : Baclini, Mrs. Solomon (Latifa Qurban)
# 859 name : Razi, Mr. Raihed
# 860 name : Hansen, Mr. Claus Peter
# 861 name : Giles, Mr. Frederick Edward
# 862 name : Swift, Mrs. Frederick Joel (Margaret Welles Barron)
# 863 name : Sage, Miss. Dorothy Edith "Dolly"
# 864 name : Gill, Mr. John William
# 865 name : Bystrom, Mrs. (Karolina)
# 866 name : Duran y More, Miss. Asuncion
# 867 name : Roebling, Mr. Washington Augustus II
# 868 name : van Melkebeke, Mr. Philemon
# 869 name : Johnson, Master. Harold Theodor
# 870 name : Balkic, Mr. Cerin
# 871 name : Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872 name : Carlsson, Mr. Frans Olof
# 873 name : Vander Cruyssen, Mr. Victor
# 874 name : Abelson, Mrs. Samuel (Hannah Wizosky)
# 875 name : Najib, Miss. Adele Kiamie "Jane"
# 876 name : Gustafsson, Mr. Alfred Ossian
# 877 name : Petroff, Mr. Nedelio
# 878 name : Laleff, Mr. Kristo
# 879 name : Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880 name : Shelley, Mrs. William (Imanita Parrish Hall)
# 881 name : Markun, Mr. Johann
# 882 name : Dahlberg, Miss. Gerda Ulrika
# 883 name : Banfield, Mr. Frederick James
# 884 name : Sutehall, Mr. Henry Jr
# 885 name : Rice, Mrs. William (Margaret Norton)
# 886 name : Montvila, Rev. Juozas
# 887 name : Graham, Miss. Margaret Edith
# 888 name : Johnston, Miss. Catherine Helen "Carrie"
# 889 name : Behr, Mr. Karl Howell
# 890 name : Dooley, Mr. Patrick

# %%
for row in df.itertuples(): # we can keep index = False, to discard the index
    print(f"{row}")
# Out:
# Pandas(Index=0, PassengerId=1, Survived=0, Pclass=3, Name='Braund, Mr. Owen Harris', Sex='male', Age=22.0, SibSp=1, Parch=0, Ticket='A/5 21171', Fare=7.25, Cabin=nan, Embarked='S')
# Pandas(Index=1, PassengerId=2, Survived=1, Pclass=1, Name='Cumings, Mrs. John Bradley (Florence Briggs Thayer)', Sex='female', Age=38.0, SibSp=1, Parch=0, Ticket='PC 17599', Fare=71.2833, Cabin='C85', Embarked='C')
# Pandas(Index=2, PassengerId=3, Survived=1, Pclass=3, Name='Heikkinen, Miss. Laina', Sex='female', Age=26.0, SibSp=0, Parch=0, Ticket='STON/O2. 3101282', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=3, PassengerId=4, Survived=1, Pclass=1, Name='Futrelle, Mrs. Jacques Heath (Lily May Peel)', Sex='female', Age=35.0, SibSp=1, Parch=0, Ticket='113803', Fare=53.1, Cabin='C123', Embarked='S')
# Pandas(Index=4, PassengerId=5, Survived=0, Pclass=3, Name='Allen, Mr. William Henry', Sex='male', Age=35.0, SibSp=0, Parch=0, Ticket='373450', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=5, PassengerId=6, Survived=0, Pclass=3, Name='Moran, Mr. James', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='330877', Fare=8.4583, Cabin=nan, Embarked='Q')
# Pandas(Index=6, PassengerId=7, Survived=0, Pclass=1, Name='McCarthy, Mr. Timothy J', Sex='male', Age=54.0, SibSp=0, Parch=0, Ticket='17463', Fare=51.8625, Cabin='E46', Embarked='S')
# Pandas(Index=7, PassengerId=8, Survived=0, Pclass=3, Name='Palsson, Master. Gosta Leonard', Sex='male', Age=2.0, SibSp=3, Parch=1, Ticket='349909', Fare=21.075, Cabin=nan, Embarked='S')
# Pandas(Index=8, PassengerId=9, Survived=1, Pclass=3, Name='Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', Sex='female', Age=27.0, SibSp=0, Parch=2, Ticket='347742', Fare=11.1333, Cabin=nan, Embarked='S')
# Pandas(Index=9, PassengerId=10, Survived=1, Pclass=2, Name='Nasser, Mrs. Nicholas (Adele Achem)', Sex='female', Age=14.0, SibSp=1, Parch=0, Ticket='237736', Fare=30.0708, Cabin=nan, Embarked='C')
# Pandas(Index=10, PassengerId=11, Survived=1, Pclass=3, Name='Sandstrom, Miss. Marguerite Rut', Sex='female', Age=4.0, SibSp=1, Parch=1, Ticket='PP 9549', Fare=16.7, Cabin='G6', Embarked='S')
# Pandas(Index=11, PassengerId=12, Survived=1, Pclass=1, Name='Bonnell, Miss. Elizabeth', Sex='female', Age=58.0, SibSp=0, Parch=0, Ticket='113783', Fare=26.55, Cabin='C103', Embarked='S')
# Pandas(Index=12, PassengerId=13, Survived=0, Pclass=3, Name='Saundercock, Mr. William Henry', Sex='male', Age=20.0, SibSp=0, Parch=0, Ticket='A/5. 2151', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=13, PassengerId=14, Survived=0, Pclass=3, Name='Andersson, Mr. Anders Johan', Sex='male', Age=39.0, SibSp=1, Parch=5, Ticket='347082', Fare=31.275, Cabin=nan, Embarked='S')
# Pandas(Index=14, PassengerId=15, Survived=0, Pclass=3, Name='Vestrom, Miss. Hulda Amanda Adolfina', Sex='female', Age=14.0, SibSp=0, Parch=0, Ticket='350406', Fare=7.8542, Cabin=nan, Embarked='S')
# Pandas(Index=15, PassengerId=16, Survived=1, Pclass=2, Name='Hewlett, Mrs. (Mary D Kingcome) ', Sex='female', Age=55.0, SibSp=0, Parch=0, Ticket='248706', Fare=16.0, Cabin=nan, Embarked='S')
# Pandas(Index=16, PassengerId=17, Survived=0, Pclass=3, Name='Rice, Master. Eugene', Sex='male', Age=2.0, SibSp=4, Parch=1, Ticket='382652', Fare=29.125, Cabin=nan, Embarked='Q')
# Pandas(Index=17, PassengerId=18, Survived=1, Pclass=2, Name='Williams, Mr. Charles Eugene', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='244373', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=18, PassengerId=19, Survived=0, Pclass=3, Name='Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)', Sex='female', Age=31.0, SibSp=1, Parch=0, Ticket='345763', Fare=18.0, Cabin=nan, Embarked='S')
# Pandas(Index=19, PassengerId=20, Survived=1, Pclass=3, Name='Masselmani, Mrs. Fatima', Sex='female', Age=nan, SibSp=0, Parch=0, Ticket='2649', Fare=7.225, Cabin=nan, Embarked='C')
# Pandas(Index=20, PassengerId=21, Survived=0, Pclass=2, Name='Fynney, Mr. Joseph J', Sex='male', Age=35.0, SibSp=0, Parch=0, Ticket='239865', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=21, PassengerId=22, Survived=1, Pclass=2, Name='Beesley, Mr. Lawrence', Sex='male', Age=34.0, SibSp=0, Parch=0, Ticket='248698', Fare=13.0, Cabin='D56', Embarked='S')
# Pandas(Index=22, PassengerId=23, Survived=1, Pclass=3, Name='McGowan, Miss. Anna "Annie"', Sex='female', Age=15.0, SibSp=0, Parch=0, Ticket='330923', Fare=8.0292, Cabin=nan, Embarked='Q')
# Pandas(Index=23, PassengerId=24, Survived=1, Pclass=1, Name='Sloper, Mr. William Thompson', Sex='male', Age=28.0, SibSp=0, Parch=0, Ticket='113788', Fare=35.5, Cabin='A6', Embarked='S')
# Pandas(Index=24, PassengerId=25, Survived=0, Pclass=3, Name='Palsson, Miss. Torborg Danira', Sex='female', Age=8.0, SibSp=3, Parch=1, Ticket='349909', Fare=21.075, Cabin=nan, Embarked='S')
# Pandas(Index=25, PassengerId=26, Survived=1, Pclass=3, Name='Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)', Sex='female', Age=38.0, SibSp=1, Parch=5, Ticket='347077', Fare=31.3875, Cabin=nan, Embarked='S')
# Pandas(Index=26, PassengerId=27, Survived=0, Pclass=3, Name='Emir, Mr. Farred Chehab', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='2631', Fare=7.225, Cabin=nan, Embarked='C')
# Pandas(Index=27, PassengerId=28, Survived=0, Pclass=1, Name='Fortune, Mr. Charles Alexander', Sex='male', Age=19.0, SibSp=3, Parch=2, Ticket='19950', Fare=263.0, Cabin='C23 C25 C27', Embarked='S')
# Pandas(Index=28, PassengerId=29, Survived=1, Pclass=3, Name='O\'Dwyer, Miss. Ellen "Nellie"', Sex='female', Age=nan, SibSp=0, Parch=0, Ticket='330959', Fare=7.8792, Cabin=nan, Embarked='Q')
# Pandas(Index=29, PassengerId=30, Survived=0, Pclass=3, Name='Todoroff, Mr. Lalio', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='349216', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=30, PassengerId=31, Survived=0, Pclass=1, Name='Uruchurtu, Don. Manuel E', Sex='male', Age=40.0, SibSp=0, Parch=0, Ticket='PC 17601', Fare=27.7208, Cabin=nan, Embarked='C')
# Pandas(Index=31, PassengerId=32, Survived=1, Pclass=1, Name='Spencer, Mrs. William Augustus (Marie Eugenie)', Sex='female', Age=nan, SibSp=1, Parch=0, Ticket='PC 17569', Fare=146.5208, Cabin='B78', Embarked='C')
# Pandas(Index=32, PassengerId=33, Survived=1, Pclass=3, Name='Glynn, Miss. Mary Agatha', Sex='female', Age=nan, SibSp=0, Parch=0, Ticket='335677', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=33, PassengerId=34, Survived=0, Pclass=2, Name='Wheadon, Mr. Edward H', Sex='male', Age=66.0, SibSp=0, Parch=0, Ticket='C.A. 24579', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=34, PassengerId=35, Survived=0, Pclass=1, Name='Meyer, Mr. Edgar Joseph', Sex='male', Age=28.0, SibSp=1, Parch=0, Ticket='PC 17604', Fare=82.1708, Cabin=nan, Embarked='C')
# Pandas(Index=35, PassengerId=36, Survived=0, Pclass=1, Name='Holverson, Mr. Alexander Oskar', Sex='male', Age=42.0, SibSp=1, Parch=0, Ticket='113789', Fare=52.0, Cabin=nan, Embarked='S')
# Pandas(Index=36, PassengerId=37, Survived=1, Pclass=3, Name='Mamee, Mr. Hanna', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='2677', Fare=7.2292, Cabin=nan, Embarked='C')
# Pandas(Index=37, PassengerId=38, Survived=0, Pclass=3, Name='Cann, Mr. Ernest Charles', Sex='male', Age=21.0, SibSp=0, Parch=0, Ticket='A./5. 2152', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=38, PassengerId=39, Survived=0, Pclass=3, Name='Vander Planke, Miss. Augusta Maria', Sex='female', Age=18.0, SibSp=2, Parch=0, Ticket='345764', Fare=18.0, Cabin=nan, Embarked='S')
# Pandas(Index=39, PassengerId=40, Survived=1, Pclass=3, Name='Nicola-Yarred, Miss. Jamila', Sex='female', Age=14.0, SibSp=1, Parch=0, Ticket='2651', Fare=11.2417, Cabin=nan, Embarked='C')
# Pandas(Index=40, PassengerId=41, Survived=0, Pclass=3, Name='Ahlin, Mrs. Johan (Johanna Persdotter Larsson)', Sex='female', Age=40.0, SibSp=1, Parch=0, Ticket='7546', Fare=9.475, Cabin=nan, Embarked='S')
# Pandas(Index=41, PassengerId=42, Survived=0, Pclass=2, Name='Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)', Sex='female', Age=27.0, SibSp=1, Parch=0, Ticket='11668', Fare=21.0, Cabin=nan, Embarked='S')
# Pandas(Index=42, PassengerId=43, Survived=0, Pclass=3, Name='Kraeff, Mr. Theodor', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='349253', Fare=7.8958, Cabin=nan, Embarked='C')
# Pandas(Index=43, PassengerId=44, Survived=1, Pclass=2, Name='Laroche, Miss. Simonne Marie Anne Andree', Sex='female', Age=3.0, SibSp=1, Parch=2, Ticket='SC/Paris 2123', Fare=41.5792, Cabin=nan, Embarked='C')
# Pandas(Index=44, PassengerId=45, Survived=1, Pclass=3, Name='Devaney, Miss. Margaret Delia', Sex='female', Age=19.0, SibSp=0, Parch=0, Ticket='330958', Fare=7.8792, Cabin=nan, Embarked='Q')
# Pandas(Index=45, PassengerId=46, Survived=0, Pclass=3, Name='Rogers, Mr. William John', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='S.C./A.4. 23567', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=46, PassengerId=47, Survived=0, Pclass=3, Name='Lennon, Mr. Denis', Sex='male', Age=nan, SibSp=1, Parch=0, Ticket='370371', Fare=15.5, Cabin=nan, Embarked='Q')
# Pandas(Index=47, PassengerId=48, Survived=1, Pclass=3, Name="O'Driscoll, Miss. Bridget", Sex='female', Age=nan, SibSp=0, Parch=0, Ticket='14311', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=48, PassengerId=49, Survived=0, Pclass=3, Name='Samaan, Mr. Youssef', Sex='male', Age=nan, SibSp=2, Parch=0, Ticket='2662', Fare=21.6792, Cabin=nan, Embarked='C')
# Pandas(Index=49, PassengerId=50, Survived=0, Pclass=3, Name='Arnold-Franchi, Mrs. Josef (Josefine Franchi)', Sex='female', Age=18.0, SibSp=1, Parch=0, Ticket='349237', Fare=17.8, Cabin=nan, Embarked='S')
# Pandas(Index=50, PassengerId=51, Survived=0, Pclass=3, Name='Panula, Master. Juha Niilo', Sex='male', Age=7.0, SibSp=4, Parch=1, Ticket='3101295', Fare=39.6875, Cabin=nan, Embarked='S')
# Pandas(Index=51, PassengerId=52, Survived=0, Pclass=3, Name='Nosworthy, Mr. Richard Cater', Sex='male', Age=21.0, SibSp=0, Parch=0, Ticket='A/4. 39886', Fare=7.8, Cabin=nan, Embarked='S')
# Pandas(Index=52, PassengerId=53, Survived=1, Pclass=1, Name='Harper, Mrs. Henry Sleeper (Myna Haxtun)', Sex='female', Age=49.0, SibSp=1, Parch=0, Ticket='PC 17572', Fare=76.7292, Cabin='D33', Embarked='C')
# Pandas(Index=53, PassengerId=54, Survived=1, Pclass=2, Name='Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)', Sex='female', Age=29.0, SibSp=1, Parch=0, Ticket='2926', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=54, PassengerId=55, Survived=0, Pclass=1, Name='Ostby, Mr. Engelhart Cornelius', Sex='male', Age=65.0, SibSp=0, Parch=1, Ticket='113509', Fare=61.9792, Cabin='B30', Embarked='C')
# Pandas(Index=55, PassengerId=56, Survived=1, Pclass=1, Name='Woolner, Mr. Hugh', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='19947', Fare=35.5, Cabin='C52', Embarked='S')
# Pandas(Index=56, PassengerId=57, Survived=1, Pclass=2, Name='Rugg, Miss. Emily', Sex='female', Age=21.0, SibSp=0, Parch=0, Ticket='C.A. 31026', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=57, PassengerId=58, Survived=0, Pclass=3, Name='Novel, Mr. Mansouer', Sex='male', Age=28.5, SibSp=0, Parch=0, Ticket='2697', Fare=7.2292, Cabin=nan, Embarked='C')
# Pandas(Index=58, PassengerId=59, Survived=1, Pclass=2, Name='West, Miss. Constance Mirium', Sex='female', Age=5.0, SibSp=1, Parch=2, Ticket='C.A. 34651', Fare=27.75, Cabin=nan, Embarked='S')
# Pandas(Index=59, PassengerId=60, Survived=0, Pclass=3, Name='Goodwin, Master. William Frederick', Sex='male', Age=11.0, SibSp=5, Parch=2, Ticket='CA 2144', Fare=46.9, Cabin=nan, Embarked='S')
# Pandas(Index=60, PassengerId=61, Survived=0, Pclass=3, Name='Sirayanian, Mr. Orsen', Sex='male', Age=22.0, SibSp=0, Parch=0, Ticket='2669', Fare=7.2292, Cabin=nan, Embarked='C')
# Pandas(Index=61, PassengerId=62, Survived=1, Pclass=1, Name='Icard, Miss. Amelie', Sex='female', Age=38.0, SibSp=0, Parch=0, Ticket='113572', Fare=80.0, Cabin='B28', Embarked=nan)
# Pandas(Index=62, PassengerId=63, Survived=0, Pclass=1, Name='Harris, Mr. Henry Birkhardt', Sex='male', Age=45.0, SibSp=1, Parch=0, Ticket='36973', Fare=83.475, Cabin='C83', Embarked='S')
# Pandas(Index=63, PassengerId=64, Survived=0, Pclass=3, Name='Skoog, Master. Harald', Sex='male', Age=4.0, SibSp=3, Parch=2, Ticket='347088', Fare=27.9, Cabin=nan, Embarked='S')
# Pandas(Index=64, PassengerId=65, Survived=0, Pclass=1, Name='Stewart, Mr. Albert A', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='PC 17605', Fare=27.7208, Cabin=nan, Embarked='C')
# Pandas(Index=65, PassengerId=66, Survived=1, Pclass=3, Name='Moubarek, Master. Gerios', Sex='male', Age=nan, SibSp=1, Parch=1, Ticket='2661', Fare=15.2458, Cabin=nan, Embarked='C')
# Pandas(Index=66, PassengerId=67, Survived=1, Pclass=2, Name='Nye, Mrs. (Elizabeth Ramell)', Sex='female', Age=29.0, SibSp=0, Parch=0, Ticket='C.A. 29395', Fare=10.5, Cabin='F33', Embarked='S')
# Pandas(Index=67, PassengerId=68, Survived=0, Pclass=3, Name='Crease, Mr. Ernest James', Sex='male', Age=19.0, SibSp=0, Parch=0, Ticket='S.P. 3464', Fare=8.1583, Cabin=nan, Embarked='S')
# Pandas(Index=68, PassengerId=69, Survived=1, Pclass=3, Name='Andersson, Miss. Erna Alexandra', Sex='female', Age=17.0, SibSp=4, Parch=2, Ticket='3101281', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=69, PassengerId=70, Survived=0, Pclass=3, Name='Kink, Mr. Vincenz', Sex='male', Age=26.0, SibSp=2, Parch=0, Ticket='315151', Fare=8.6625, Cabin=nan, Embarked='S')
# Pandas(Index=70, PassengerId=71, Survived=0, Pclass=2, Name='Jenkin, Mr. Stephen Curnow', Sex='male', Age=32.0, SibSp=0, Parch=0, Ticket='C.A. 33111', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=71, PassengerId=72, Survived=0, Pclass=3, Name='Goodwin, Miss. Lillian Amy', Sex='female', Age=16.0, SibSp=5, Parch=2, Ticket='CA 2144', Fare=46.9, Cabin=nan, Embarked='S')
# Pandas(Index=72, PassengerId=73, Survived=0, Pclass=2, Name='Hood, Mr. Ambrose Jr', Sex='male', Age=21.0, SibSp=0, Parch=0, Ticket='S.O.C. 14879', Fare=73.5, Cabin=nan, Embarked='S')
# Pandas(Index=73, PassengerId=74, Survived=0, Pclass=3, Name='Chronopoulos, Mr. Apostolos', Sex='male', Age=26.0, SibSp=1, Parch=0, Ticket='2680', Fare=14.4542, Cabin=nan, Embarked='C')
# Pandas(Index=74, PassengerId=75, Survived=1, Pclass=3, Name='Bing, Mr. Lee', Sex='male', Age=32.0, SibSp=0, Parch=0, Ticket='1601', Fare=56.4958, Cabin=nan, Embarked='S')
# Pandas(Index=75, PassengerId=76, Survived=0, Pclass=3, Name='Moen, Mr. Sigurd Hansen', Sex='male', Age=25.0, SibSp=0, Parch=0, Ticket='348123', Fare=7.65, Cabin='F G73', Embarked='S')
# Pandas(Index=76, PassengerId=77, Survived=0, Pclass=3, Name='Staneff, Mr. Ivan', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='349208', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=77, PassengerId=78, Survived=0, Pclass=3, Name='Moutal, Mr. Rahamin Haim', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='374746', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=78, PassengerId=79, Survived=1, Pclass=2, Name='Caldwell, Master. Alden Gates', Sex='male', Age=0.83, SibSp=0, Parch=2, Ticket='248738', Fare=29.0, Cabin=nan, Embarked='S')
# Pandas(Index=79, PassengerId=80, Survived=1, Pclass=3, Name='Dowdell, Miss. Elizabeth', Sex='female', Age=30.0, SibSp=0, Parch=0, Ticket='364516', Fare=12.475, Cabin=nan, Embarked='S')
# Pandas(Index=80, PassengerId=81, Survived=0, Pclass=3, Name='Waelens, Mr. Achille', Sex='male', Age=22.0, SibSp=0, Parch=0, Ticket='345767', Fare=9.0, Cabin=nan, Embarked='S')
# Pandas(Index=81, PassengerId=82, Survived=1, Pclass=3, Name='Sheerlinck, Mr. Jan Baptist', Sex='male', Age=29.0, SibSp=0, Parch=0, Ticket='345779', Fare=9.5, Cabin=nan, Embarked='S')
# Pandas(Index=82, PassengerId=83, Survived=1, Pclass=3, Name='McDermott, Miss. Brigdet Delia', Sex='female', Age=nan, SibSp=0, Parch=0, Ticket='330932', Fare=7.7875, Cabin=nan, Embarked='Q')
# Pandas(Index=83, PassengerId=84, Survived=0, Pclass=1, Name='Carrau, Mr. Francisco M', Sex='male', Age=28.0, SibSp=0, Parch=0, Ticket='113059', Fare=47.1, Cabin=nan, Embarked='S')
# Pandas(Index=84, PassengerId=85, Survived=1, Pclass=2, Name='Ilett, Miss. Bertha', Sex='female', Age=17.0, SibSp=0, Parch=0, Ticket='SO/C 14885', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=85, PassengerId=86, Survived=1, Pclass=3, Name='Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)', Sex='female', Age=33.0, SibSp=3, Parch=0, Ticket='3101278', Fare=15.85, Cabin=nan, Embarked='S')
# Pandas(Index=86, PassengerId=87, Survived=0, Pclass=3, Name='Ford, Mr. William Neal', Sex='male', Age=16.0, SibSp=1, Parch=3, Ticket='W./C. 6608', Fare=34.375, Cabin=nan, Embarked='S')
# Pandas(Index=87, PassengerId=88, Survived=0, Pclass=3, Name='Slocovski, Mr. Selman Francis', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='SOTON/OQ 392086', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=88, PassengerId=89, Survived=1, Pclass=1, Name='Fortune, Miss. Mabel Helen', Sex='female', Age=23.0, SibSp=3, Parch=2, Ticket='19950', Fare=263.0, Cabin='C23 C25 C27', Embarked='S')
# Pandas(Index=89, PassengerId=90, Survived=0, Pclass=3, Name='Celotti, Mr. Francesco', Sex='male', Age=24.0, SibSp=0, Parch=0, Ticket='343275', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=90, PassengerId=91, Survived=0, Pclass=3, Name='Christmann, Mr. Emil', Sex='male', Age=29.0, SibSp=0, Parch=0, Ticket='343276', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=91, PassengerId=92, Survived=0, Pclass=3, Name='Andreasson, Mr. Paul Edvin', Sex='male', Age=20.0, SibSp=0, Parch=0, Ticket='347466', Fare=7.8542, Cabin=nan, Embarked='S')
# Pandas(Index=92, PassengerId=93, Survived=0, Pclass=1, Name='Chaffee, Mr. Herbert Fuller', Sex='male', Age=46.0, SibSp=1, Parch=0, Ticket='W.E.P. 5734', Fare=61.175, Cabin='E31', Embarked='S')
# Pandas(Index=93, PassengerId=94, Survived=0, Pclass=3, Name='Dean, Mr. Bertram Frank', Sex='male', Age=26.0, SibSp=1, Parch=2, Ticket='C.A. 2315', Fare=20.575, Cabin=nan, Embarked='S')
# Pandas(Index=94, PassengerId=95, Survived=0, Pclass=3, Name='Coxon, Mr. Daniel', Sex='male', Age=59.0, SibSp=0, Parch=0, Ticket='364500', Fare=7.25, Cabin=nan, Embarked='S')
# Pandas(Index=95, PassengerId=96, Survived=0, Pclass=3, Name='Shorney, Mr. Charles Joseph', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='374910', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=96, PassengerId=97, Survived=0, Pclass=1, Name='Goldschmidt, Mr. George B', Sex='male', Age=71.0, SibSp=0, Parch=0, Ticket='PC 17754', Fare=34.6542, Cabin='A5', Embarked='C')
# Pandas(Index=97, PassengerId=98, Survived=1, Pclass=1, Name='Greenfield, Mr. William Bertram', Sex='male', Age=23.0, SibSp=0, Parch=1, Ticket='PC 17759', Fare=63.3583, Cabin='D10 D12', Embarked='C')
# Pandas(Index=98, PassengerId=99, Survived=1, Pclass=2, Name='Doling, Mrs. John T (Ada Julia Bone)', Sex='female', Age=34.0, SibSp=0, Parch=1, Ticket='231919', Fare=23.0, Cabin=nan, Embarked='S')
# Pandas(Index=99, PassengerId=100, Survived=0, Pclass=2, Name='Kantor, Mr. Sinai', Sex='male', Age=34.0, SibSp=1, Parch=0, Ticket='244367', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=100, PassengerId=101, Survived=0, Pclass=3, Name='Petranec, Miss. Matilda', Sex='female', Age=28.0, SibSp=0, Parch=0, Ticket='349245', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=101, PassengerId=102, Survived=0, Pclass=3, Name='Petroff, Mr. Pastcho ("Pentcho")', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='349215', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=102, PassengerId=103, Survived=0, Pclass=1, Name='White, Mr. Richard Frasar', Sex='male', Age=21.0, SibSp=0, Parch=1, Ticket='35281', Fare=77.2875, Cabin='D26', Embarked='S')
# Pandas(Index=103, PassengerId=104, Survived=0, Pclass=3, Name='Johansson, Mr. Gustaf Joel', Sex='male', Age=33.0, SibSp=0, Parch=0, Ticket='7540', Fare=8.6542, Cabin=nan, Embarked='S')
# Pandas(Index=104, PassengerId=105, Survived=0, Pclass=3, Name='Gustafsson, Mr. Anders Vilhelm', Sex='male', Age=37.0, SibSp=2, Parch=0, Ticket='3101276', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=105, PassengerId=106, Survived=0, Pclass=3, Name='Mionoff, Mr. Stoytcho', Sex='male', Age=28.0, SibSp=0, Parch=0, Ticket='349207', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=106, PassengerId=107, Survived=1, Pclass=3, Name='Salkjelsvik, Miss. Anna Kristine', Sex='female', Age=21.0, SibSp=0, Parch=0, Ticket='343120', Fare=7.65, Cabin=nan, Embarked='S')
# Pandas(Index=107, PassengerId=108, Survived=1, Pclass=3, Name='Moss, Mr. Albert Johan', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='312991', Fare=7.775, Cabin=nan, Embarked='S')
# Pandas(Index=108, PassengerId=109, Survived=0, Pclass=3, Name='Rekic, Mr. Tido', Sex='male', Age=38.0, SibSp=0, Parch=0, Ticket='349249', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=109, PassengerId=110, Survived=1, Pclass=3, Name='Moran, Miss. Bertha', Sex='female', Age=nan, SibSp=1, Parch=0, Ticket='371110', Fare=24.15, Cabin=nan, Embarked='Q')
# Pandas(Index=110, PassengerId=111, Survived=0, Pclass=1, Name='Porter, Mr. Walter Chamberlain', Sex='male', Age=47.0, SibSp=0, Parch=0, Ticket='110465', Fare=52.0, Cabin='C110', Embarked='S')
# Pandas(Index=111, PassengerId=112, Survived=0, Pclass=3, Name='Zabour, Miss. Hileni', Sex='female', Age=14.5, SibSp=1, Parch=0, Ticket='2665', Fare=14.4542, Cabin=nan, Embarked='C')
# Pandas(Index=112, PassengerId=113, Survived=0, Pclass=3, Name='Barton, Mr. David John', Sex='male', Age=22.0, SibSp=0, Parch=0, Ticket='324669', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=113, PassengerId=114, Survived=0, Pclass=3, Name='Jussila, Miss. Katriina', Sex='female', Age=20.0, SibSp=1, Parch=0, Ticket='4136', Fare=9.825, Cabin=nan, Embarked='S')
# Pandas(Index=114, PassengerId=115, Survived=0, Pclass=3, Name='Attalah, Miss. Malake', Sex='female', Age=17.0, SibSp=0, Parch=0, Ticket='2627', Fare=14.4583, Cabin=nan, Embarked='C')
# Pandas(Index=115, PassengerId=116, Survived=0, Pclass=3, Name='Pekoniemi, Mr. Edvard', Sex='male', Age=21.0, SibSp=0, Parch=0, Ticket='STON/O 2. 3101294', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=116, PassengerId=117, Survived=0, Pclass=3, Name='Connors, Mr. Patrick', Sex='male', Age=70.5, SibSp=0, Parch=0, Ticket='370369', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=117, PassengerId=118, Survived=0, Pclass=2, Name='Turpin, Mr. William John Robert', Sex='male', Age=29.0, SibSp=1, Parch=0, Ticket='11668', Fare=21.0, Cabin=nan, Embarked='S')
# Pandas(Index=118, PassengerId=119, Survived=0, Pclass=1, Name='Baxter, Mr. Quigg Edmond', Sex='male', Age=24.0, SibSp=0, Parch=1, Ticket='PC 17558', Fare=247.5208, Cabin='B58 B60', Embarked='C')
# Pandas(Index=119, PassengerId=120, Survived=0, Pclass=3, Name='Andersson, Miss. Ellis Anna Maria', Sex='female', Age=2.0, SibSp=4, Parch=2, Ticket='347082', Fare=31.275, Cabin=nan, Embarked='S')
# Pandas(Index=120, PassengerId=121, Survived=0, Pclass=2, Name='Hickman, Mr. Stanley George', Sex='male', Age=21.0, SibSp=2, Parch=0, Ticket='S.O.C. 14879', Fare=73.5, Cabin=nan, Embarked='S')
# Pandas(Index=121, PassengerId=122, Survived=0, Pclass=3, Name='Moore, Mr. Leonard Charles', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='A4. 54510', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=122, PassengerId=123, Survived=0, Pclass=2, Name='Nasser, Mr. Nicholas', Sex='male', Age=32.5, SibSp=1, Parch=0, Ticket='237736', Fare=30.0708, Cabin=nan, Embarked='C')
# Pandas(Index=123, PassengerId=124, Survived=1, Pclass=2, Name='Webber, Miss. Susan', Sex='female', Age=32.5, SibSp=0, Parch=0, Ticket='27267', Fare=13.0, Cabin='E101', Embarked='S')
# Pandas(Index=124, PassengerId=125, Survived=0, Pclass=1, Name='White, Mr. Percival Wayland', Sex='male', Age=54.0, SibSp=0, Parch=1, Ticket='35281', Fare=77.2875, Cabin='D26', Embarked='S')
# Pandas(Index=125, PassengerId=126, Survived=1, Pclass=3, Name='Nicola-Yarred, Master. Elias', Sex='male', Age=12.0, SibSp=1, Parch=0, Ticket='2651', Fare=11.2417, Cabin=nan, Embarked='C')
# Pandas(Index=126, PassengerId=127, Survived=0, Pclass=3, Name='McMahon, Mr. Martin', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='370372', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=127, PassengerId=128, Survived=1, Pclass=3, Name='Madsen, Mr. Fridtjof Arne', Sex='male', Age=24.0, SibSp=0, Parch=0, Ticket='C 17369', Fare=7.1417, Cabin=nan, Embarked='S')
# Pandas(Index=128, PassengerId=129, Survived=1, Pclass=3, Name='Peter, Miss. Anna', Sex='female', Age=nan, SibSp=1, Parch=1, Ticket='2668', Fare=22.3583, Cabin='F E69', Embarked='C')
# Pandas(Index=129, PassengerId=130, Survived=0, Pclass=3, Name='Ekstrom, Mr. Johan', Sex='male', Age=45.0, SibSp=0, Parch=0, Ticket='347061', Fare=6.975, Cabin=nan, Embarked='S')
# Pandas(Index=130, PassengerId=131, Survived=0, Pclass=3, Name='Drazenoic, Mr. Jozef', Sex='male', Age=33.0, SibSp=0, Parch=0, Ticket='349241', Fare=7.8958, Cabin=nan, Embarked='C')
# Pandas(Index=131, PassengerId=132, Survived=0, Pclass=3, Name='Coelho, Mr. Domingos Fernandeo', Sex='male', Age=20.0, SibSp=0, Parch=0, Ticket='SOTON/O.Q. 3101307', Fare=7.05, Cabin=nan, Embarked='S')
# Pandas(Index=132, PassengerId=133, Survived=0, Pclass=3, Name='Robins, Mrs. Alexander A (Grace Charity Laury)', Sex='female', Age=47.0, SibSp=1, Parch=0, Ticket='A/5. 3337', Fare=14.5, Cabin=nan, Embarked='S')
# Pandas(Index=133, PassengerId=134, Survived=1, Pclass=2, Name='Weisz, Mrs. Leopold (Mathilde Francoise Pede)', Sex='female', Age=29.0, SibSp=1, Parch=0, Ticket='228414', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=134, PassengerId=135, Survived=0, Pclass=2, Name='Sobey, Mr. Samuel James Hayden', Sex='male', Age=25.0, SibSp=0, Parch=0, Ticket='C.A. 29178', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=135, PassengerId=136, Survived=0, Pclass=2, Name='Richard, Mr. Emile', Sex='male', Age=23.0, SibSp=0, Parch=0, Ticket='SC/PARIS 2133', Fare=15.0458, Cabin=nan, Embarked='C')
# Pandas(Index=136, PassengerId=137, Survived=1, Pclass=1, Name='Newsom, Miss. Helen Monypeny', Sex='female', Age=19.0, SibSp=0, Parch=2, Ticket='11752', Fare=26.2833, Cabin='D47', Embarked='S')
# Pandas(Index=137, PassengerId=138, Survived=0, Pclass=1, Name='Futrelle, Mr. Jacques Heath', Sex='male', Age=37.0, SibSp=1, Parch=0, Ticket='113803', Fare=53.1, Cabin='C123', Embarked='S')
# Pandas(Index=138, PassengerId=139, Survived=0, Pclass=3, Name='Osen, Mr. Olaf Elon', Sex='male', Age=16.0, SibSp=0, Parch=0, Ticket='7534', Fare=9.2167, Cabin=nan, Embarked='S')
# Pandas(Index=139, PassengerId=140, Survived=0, Pclass=1, Name='Giglio, Mr. Victor', Sex='male', Age=24.0, SibSp=0, Parch=0, Ticket='PC 17593', Fare=79.2, Cabin='B86', Embarked='C')
# Pandas(Index=140, PassengerId=141, Survived=0, Pclass=3, Name='Boulos, Mrs. Joseph (Sultana)', Sex='female', Age=nan, SibSp=0, Parch=2, Ticket='2678', Fare=15.2458, Cabin=nan, Embarked='C')
# Pandas(Index=141, PassengerId=142, Survived=1, Pclass=3, Name='Nysten, Miss. Anna Sofia', Sex='female', Age=22.0, SibSp=0, Parch=0, Ticket='347081', Fare=7.75, Cabin=nan, Embarked='S')
# Pandas(Index=142, PassengerId=143, Survived=1, Pclass=3, Name='Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)', Sex='female', Age=24.0, SibSp=1, Parch=0, Ticket='STON/O2. 3101279', Fare=15.85, Cabin=nan, Embarked='S')
# Pandas(Index=143, PassengerId=144, Survived=0, Pclass=3, Name='Burke, Mr. Jeremiah', Sex='male', Age=19.0, SibSp=0, Parch=0, Ticket='365222', Fare=6.75, Cabin=nan, Embarked='Q')
# Pandas(Index=144, PassengerId=145, Survived=0, Pclass=2, Name='Andrew, Mr. Edgardo Samuel', Sex='male', Age=18.0, SibSp=0, Parch=0, Ticket='231945', Fare=11.5, Cabin=nan, Embarked='S')
# Pandas(Index=145, PassengerId=146, Survived=0, Pclass=2, Name='Nicholls, Mr. Joseph Charles', Sex='male', Age=19.0, SibSp=1, Parch=1, Ticket='C.A. 33112', Fare=36.75, Cabin=nan, Embarked='S')
# Pandas(Index=146, PassengerId=147, Survived=1, Pclass=3, Name='Andersson, Mr. August Edvard ("Wennerstrom")', Sex='male', Age=27.0, SibSp=0, Parch=0, Ticket='350043', Fare=7.7958, Cabin=nan, Embarked='S')
# Pandas(Index=147, PassengerId=148, Survived=0, Pclass=3, Name='Ford, Miss. Robina Maggie "Ruby"', Sex='female', Age=9.0, SibSp=2, Parch=2, Ticket='W./C. 6608', Fare=34.375, Cabin=nan, Embarked='S')
# Pandas(Index=148, PassengerId=149, Survived=0, Pclass=2, Name='Navratil, Mr. Michel ("Louis M Hoffman")', Sex='male', Age=36.5, SibSp=0, Parch=2, Ticket='230080', Fare=26.0, Cabin='F2', Embarked='S')
# Pandas(Index=149, PassengerId=150, Survived=0, Pclass=2, Name='Byles, Rev. Thomas Roussel Davids', Sex='male', Age=42.0, SibSp=0, Parch=0, Ticket='244310', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=150, PassengerId=151, Survived=0, Pclass=2, Name='Bateman, Rev. Robert James', Sex='male', Age=51.0, SibSp=0, Parch=0, Ticket='S.O.P. 1166', Fare=12.525, Cabin=nan, Embarked='S')
# Pandas(Index=151, PassengerId=152, Survived=1, Pclass=1, Name='Pears, Mrs. Thomas (Edith Wearne)', Sex='female', Age=22.0, SibSp=1, Parch=0, Ticket='113776', Fare=66.6, Cabin='C2', Embarked='S')
# Pandas(Index=152, PassengerId=153, Survived=0, Pclass=3, Name='Meo, Mr. Alfonzo', Sex='male', Age=55.5, SibSp=0, Parch=0, Ticket='A.5. 11206', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=153, PassengerId=154, Survived=0, Pclass=3, Name='van Billiard, Mr. Austin Blyler', Sex='male', Age=40.5, SibSp=0, Parch=2, Ticket='A/5. 851', Fare=14.5, Cabin=nan, Embarked='S')
# Pandas(Index=154, PassengerId=155, Survived=0, Pclass=3, Name='Olsen, Mr. Ole Martin', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='Fa 265302', Fare=7.3125, Cabin=nan, Embarked='S')
# Pandas(Index=155, PassengerId=156, Survived=0, Pclass=1, Name='Williams, Mr. Charles Duane', Sex='male', Age=51.0, SibSp=0, Parch=1, Ticket='PC 17597', Fare=61.3792, Cabin=nan, Embarked='C')
# Pandas(Index=156, PassengerId=157, Survived=1, Pclass=3, Name='Gilnagh, Miss. Katherine "Katie"', Sex='female', Age=16.0, SibSp=0, Parch=0, Ticket='35851', Fare=7.7333, Cabin=nan, Embarked='Q')
# Pandas(Index=157, PassengerId=158, Survived=0, Pclass=3, Name='Corn, Mr. Harry', Sex='male', Age=30.0, SibSp=0, Parch=0, Ticket='SOTON/OQ 392090', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=158, PassengerId=159, Survived=0, Pclass=3, Name='Smiljanic, Mr. Mile', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='315037', Fare=8.6625, Cabin=nan, Embarked='S')
# Pandas(Index=159, PassengerId=160, Survived=0, Pclass=3, Name='Sage, Master. Thomas Henry', Sex='male', Age=nan, SibSp=8, Parch=2, Ticket='CA. 2343', Fare=69.55, Cabin=nan, Embarked='S')
# Pandas(Index=160, PassengerId=161, Survived=0, Pclass=3, Name='Cribb, Mr. John Hatfield', Sex='male', Age=44.0, SibSp=0, Parch=1, Ticket='371362', Fare=16.1, Cabin=nan, Embarked='S')
# Pandas(Index=161, PassengerId=162, Survived=1, Pclass=2, Name='Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)', Sex='female', Age=40.0, SibSp=0, Parch=0, Ticket='C.A. 33595', Fare=15.75, Cabin=nan, Embarked='S')
# Pandas(Index=162, PassengerId=163, Survived=0, Pclass=3, Name='Bengtsson, Mr. John Viktor', Sex='male', Age=26.0, SibSp=0, Parch=0, Ticket='347068', Fare=7.775, Cabin=nan, Embarked='S')
# Pandas(Index=163, PassengerId=164, Survived=0, Pclass=3, Name='Calic, Mr. Jovo', Sex='male', Age=17.0, SibSp=0, Parch=0, Ticket='315093', Fare=8.6625, Cabin=nan, Embarked='S')
# Pandas(Index=164, PassengerId=165, Survived=0, Pclass=3, Name='Panula, Master. Eino Viljami', Sex='male', Age=1.0, SibSp=4, Parch=1, Ticket='3101295', Fare=39.6875, Cabin=nan, Embarked='S')
# Pandas(Index=165, PassengerId=166, Survived=1, Pclass=3, Name='Goldsmith, Master. Frank John William "Frankie"', Sex='male', Age=9.0, SibSp=0, Parch=2, Ticket='363291', Fare=20.525, Cabin=nan, Embarked='S')
# Pandas(Index=166, PassengerId=167, Survived=1, Pclass=1, Name='Chibnall, Mrs. (Edith Martha Bowerman)', Sex='female', Age=nan, SibSp=0, Parch=1, Ticket='113505', Fare=55.0, Cabin='E33', Embarked='S')
# Pandas(Index=167, PassengerId=168, Survived=0, Pclass=3, Name='Skoog, Mrs. William (Anna Bernhardina Karlsson)', Sex='female', Age=45.0, SibSp=1, Parch=4, Ticket='347088', Fare=27.9, Cabin=nan, Embarked='S')
# Pandas(Index=168, PassengerId=169, Survived=0, Pclass=1, Name='Baumann, Mr. John D', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='PC 17318', Fare=25.925, Cabin=nan, Embarked='S')
# Pandas(Index=169, PassengerId=170, Survived=0, Pclass=3, Name='Ling, Mr. Lee', Sex='male', Age=28.0, SibSp=0, Parch=0, Ticket='1601', Fare=56.4958, Cabin=nan, Embarked='S')
# Pandas(Index=170, PassengerId=171, Survived=0, Pclass=1, Name='Van der hoef, Mr. Wyckoff', Sex='male', Age=61.0, SibSp=0, Parch=0, Ticket='111240', Fare=33.5, Cabin='B19', Embarked='S')
# Pandas(Index=171, PassengerId=172, Survived=0, Pclass=3, Name='Rice, Master. Arthur', Sex='male', Age=4.0, SibSp=4, Parch=1, Ticket='382652', Fare=29.125, Cabin=nan, Embarked='Q')
# Pandas(Index=172, PassengerId=173, Survived=1, Pclass=3, Name='Johnson, Miss. Eleanor Ileen', Sex='female', Age=1.0, SibSp=1, Parch=1, Ticket='347742', Fare=11.1333, Cabin=nan, Embarked='S')
# Pandas(Index=173, PassengerId=174, Survived=0, Pclass=3, Name='Sivola, Mr. Antti Wilhelm', Sex='male', Age=21.0, SibSp=0, Parch=0, Ticket='STON/O 2. 3101280', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=174, PassengerId=175, Survived=0, Pclass=1, Name='Smith, Mr. James Clinch', Sex='male', Age=56.0, SibSp=0, Parch=0, Ticket='17764', Fare=30.6958, Cabin='A7', Embarked='C')
# Pandas(Index=175, PassengerId=176, Survived=0, Pclass=3, Name='Klasen, Mr. Klas Albin', Sex='male', Age=18.0, SibSp=1, Parch=1, Ticket='350404', Fare=7.8542, Cabin=nan, Embarked='S')
# Pandas(Index=176, PassengerId=177, Survived=0, Pclass=3, Name='Lefebre, Master. Henry Forbes', Sex='male', Age=nan, SibSp=3, Parch=1, Ticket='4133', Fare=25.4667, Cabin=nan, Embarked='S')
# Pandas(Index=177, PassengerId=178, Survived=0, Pclass=1, Name='Isham, Miss. Ann Elizabeth', Sex='female', Age=50.0, SibSp=0, Parch=0, Ticket='PC 17595', Fare=28.7125, Cabin='C49', Embarked='C')
# Pandas(Index=178, PassengerId=179, Survived=0, Pclass=2, Name='Hale, Mr. Reginald', Sex='male', Age=30.0, SibSp=0, Parch=0, Ticket='250653', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=179, PassengerId=180, Survived=0, Pclass=3, Name='Leonard, Mr. Lionel', Sex='male', Age=36.0, SibSp=0, Parch=0, Ticket='LINE', Fare=0.0, Cabin=nan, Embarked='S')
# Pandas(Index=180, PassengerId=181, Survived=0, Pclass=3, Name='Sage, Miss. Constance Gladys', Sex='female', Age=nan, SibSp=8, Parch=2, Ticket='CA. 2343', Fare=69.55, Cabin=nan, Embarked='S')
# Pandas(Index=181, PassengerId=182, Survived=0, Pclass=2, Name='Pernot, Mr. Rene', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='SC/PARIS 2131', Fare=15.05, Cabin=nan, Embarked='C')
# Pandas(Index=182, PassengerId=183, Survived=0, Pclass=3, Name='Asplund, Master. Clarence Gustaf Hugo', Sex='male', Age=9.0, SibSp=4, Parch=2, Ticket='347077', Fare=31.3875, Cabin=nan, Embarked='S')
# Pandas(Index=183, PassengerId=184, Survived=1, Pclass=2, Name='Becker, Master. Richard F', Sex='male', Age=1.0, SibSp=2, Parch=1, Ticket='230136', Fare=39.0, Cabin='F4', Embarked='S')
# Pandas(Index=184, PassengerId=185, Survived=1, Pclass=3, Name='Kink-Heilmann, Miss. Luise Gretchen', Sex='female', Age=4.0, SibSp=0, Parch=2, Ticket='315153', Fare=22.025, Cabin=nan, Embarked='S')
# Pandas(Index=185, PassengerId=186, Survived=0, Pclass=1, Name='Rood, Mr. Hugh Roscoe', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='113767', Fare=50.0, Cabin='A32', Embarked='S')
# Pandas(Index=186, PassengerId=187, Survived=1, Pclass=3, Name='O\'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)', Sex='female', Age=nan, SibSp=1, Parch=0, Ticket='370365', Fare=15.5, Cabin=nan, Embarked='Q')
# Pandas(Index=187, PassengerId=188, Survived=1, Pclass=1, Name='Romaine, Mr. Charles Hallace ("Mr C Rolmane")', Sex='male', Age=45.0, SibSp=0, Parch=0, Ticket='111428', Fare=26.55, Cabin=nan, Embarked='S')
# Pandas(Index=188, PassengerId=189, Survived=0, Pclass=3, Name='Bourke, Mr. John', Sex='male', Age=40.0, SibSp=1, Parch=1, Ticket='364849', Fare=15.5, Cabin=nan, Embarked='Q')
# Pandas(Index=189, PassengerId=190, Survived=0, Pclass=3, Name='Turcin, Mr. Stjepan', Sex='male', Age=36.0, SibSp=0, Parch=0, Ticket='349247', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=190, PassengerId=191, Survived=1, Pclass=2, Name='Pinsky, Mrs. (Rosa)', Sex='female', Age=32.0, SibSp=0, Parch=0, Ticket='234604', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=191, PassengerId=192, Survived=0, Pclass=2, Name='Carbines, Mr. William', Sex='male', Age=19.0, SibSp=0, Parch=0, Ticket='28424', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=192, PassengerId=193, Survived=1, Pclass=3, Name='Andersen-Jensen, Miss. Carla Christine Nielsine', Sex='female', Age=19.0, SibSp=1, Parch=0, Ticket='350046', Fare=7.8542, Cabin=nan, Embarked='S')
# Pandas(Index=193, PassengerId=194, Survived=1, Pclass=2, Name='Navratil, Master. Michel M', Sex='male', Age=3.0, SibSp=1, Parch=1, Ticket='230080', Fare=26.0, Cabin='F2', Embarked='S')
# Pandas(Index=194, PassengerId=195, Survived=1, Pclass=1, Name='Brown, Mrs. James Joseph (Margaret Tobin)', Sex='female', Age=44.0, SibSp=0, Parch=0, Ticket='PC 17610', Fare=27.7208, Cabin='B4', Embarked='C')
# Pandas(Index=195, PassengerId=196, Survived=1, Pclass=1, Name='Lurette, Miss. Elise', Sex='female', Age=58.0, SibSp=0, Parch=0, Ticket='PC 17569', Fare=146.5208, Cabin='B80', Embarked='C')
# Pandas(Index=196, PassengerId=197, Survived=0, Pclass=3, Name='Mernagh, Mr. Robert', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='368703', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=197, PassengerId=198, Survived=0, Pclass=3, Name='Olsen, Mr. Karl Siegwart Andreas', Sex='male', Age=42.0, SibSp=0, Parch=1, Ticket='4579', Fare=8.4042, Cabin=nan, Embarked='S')
# Pandas(Index=198, PassengerId=199, Survived=1, Pclass=3, Name='Madigan, Miss. Margaret "Maggie"', Sex='female', Age=nan, SibSp=0, Parch=0, Ticket='370370', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=199, PassengerId=200, Survived=0, Pclass=2, Name='Yrois, Miss. Henriette ("Mrs Harbeck")', Sex='female', Age=24.0, SibSp=0, Parch=0, Ticket='248747', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=200, PassengerId=201, Survived=0, Pclass=3, Name='Vande Walle, Mr. Nestor Cyriel', Sex='male', Age=28.0, SibSp=0, Parch=0, Ticket='345770', Fare=9.5, Cabin=nan, Embarked='S')
# Pandas(Index=201, PassengerId=202, Survived=0, Pclass=3, Name='Sage, Mr. Frederick', Sex='male', Age=nan, SibSp=8, Parch=2, Ticket='CA. 2343', Fare=69.55, Cabin=nan, Embarked='S')
# Pandas(Index=202, PassengerId=203, Survived=0, Pclass=3, Name='Johanson, Mr. Jakob Alfred', Sex='male', Age=34.0, SibSp=0, Parch=0, Ticket='3101264', Fare=6.4958, Cabin=nan, Embarked='S')
# Pandas(Index=203, PassengerId=204, Survived=0, Pclass=3, Name='Youseff, Mr. Gerious', Sex='male', Age=45.5, SibSp=0, Parch=0, Ticket='2628', Fare=7.225, Cabin=nan, Embarked='C')
# Pandas(Index=204, PassengerId=205, Survived=1, Pclass=3, Name='Cohen, Mr. Gurshon "Gus"', Sex='male', Age=18.0, SibSp=0, Parch=0, Ticket='A/5 3540', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=205, PassengerId=206, Survived=0, Pclass=3, Name='Strom, Miss. Telma Matilda', Sex='female', Age=2.0, SibSp=0, Parch=1, Ticket='347054', Fare=10.4625, Cabin='G6', Embarked='S')
# Pandas(Index=206, PassengerId=207, Survived=0, Pclass=3, Name='Backstrom, Mr. Karl Alfred', Sex='male', Age=32.0, SibSp=1, Parch=0, Ticket='3101278', Fare=15.85, Cabin=nan, Embarked='S')
# Pandas(Index=207, PassengerId=208, Survived=1, Pclass=3, Name='Albimona, Mr. Nassef Cassem', Sex='male', Age=26.0, SibSp=0, Parch=0, Ticket='2699', Fare=18.7875, Cabin=nan, Embarked='C')
# Pandas(Index=208, PassengerId=209, Survived=1, Pclass=3, Name='Carr, Miss. Helen "Ellen"', Sex='female', Age=16.0, SibSp=0, Parch=0, Ticket='367231', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=209, PassengerId=210, Survived=1, Pclass=1, Name='Blank, Mr. Henry', Sex='male', Age=40.0, SibSp=0, Parch=0, Ticket='112277', Fare=31.0, Cabin='A31', Embarked='C')
# Pandas(Index=210, PassengerId=211, Survived=0, Pclass=3, Name='Ali, Mr. Ahmed', Sex='male', Age=24.0, SibSp=0, Parch=0, Ticket='SOTON/O.Q. 3101311', Fare=7.05, Cabin=nan, Embarked='S')
# Pandas(Index=211, PassengerId=212, Survived=1, Pclass=2, Name='Cameron, Miss. Clear Annie', Sex='female', Age=35.0, SibSp=0, Parch=0, Ticket='F.C.C. 13528', Fare=21.0, Cabin=nan, Embarked='S')
# Pandas(Index=212, PassengerId=213, Survived=0, Pclass=3, Name='Perkin, Mr. John Henry', Sex='male', Age=22.0, SibSp=0, Parch=0, Ticket='A/5 21174', Fare=7.25, Cabin=nan, Embarked='S')
# Pandas(Index=213, PassengerId=214, Survived=0, Pclass=2, Name='Givard, Mr. Hans Kristensen', Sex='male', Age=30.0, SibSp=0, Parch=0, Ticket='250646', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=214, PassengerId=215, Survived=0, Pclass=3, Name='Kiernan, Mr. Philip', Sex='male', Age=nan, SibSp=1, Parch=0, Ticket='367229', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=215, PassengerId=216, Survived=1, Pclass=1, Name='Newell, Miss. Madeleine', Sex='female', Age=31.0, SibSp=1, Parch=0, Ticket='35273', Fare=113.275, Cabin='D36', Embarked='C')
# Pandas(Index=216, PassengerId=217, Survived=1, Pclass=3, Name='Honkanen, Miss. Eliina', Sex='female', Age=27.0, SibSp=0, Parch=0, Ticket='STON/O2. 3101283', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=217, PassengerId=218, Survived=0, Pclass=2, Name='Jacobsohn, Mr. Sidney Samuel', Sex='male', Age=42.0, SibSp=1, Parch=0, Ticket='243847', Fare=27.0, Cabin=nan, Embarked='S')
# Pandas(Index=218, PassengerId=219, Survived=1, Pclass=1, Name='Bazzani, Miss. Albina', Sex='female', Age=32.0, SibSp=0, Parch=0, Ticket='11813', Fare=76.2917, Cabin='D15', Embarked='C')
# Pandas(Index=219, PassengerId=220, Survived=0, Pclass=2, Name='Harris, Mr. Walter', Sex='male', Age=30.0, SibSp=0, Parch=0, Ticket='W/C 14208', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=220, PassengerId=221, Survived=1, Pclass=3, Name='Sunderland, Mr. Victor Francis', Sex='male', Age=16.0, SibSp=0, Parch=0, Ticket='SOTON/OQ 392089', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=221, PassengerId=222, Survived=0, Pclass=2, Name='Bracken, Mr. James H', Sex='male', Age=27.0, SibSp=0, Parch=0, Ticket='220367', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=222, PassengerId=223, Survived=0, Pclass=3, Name='Green, Mr. George Henry', Sex='male', Age=51.0, SibSp=0, Parch=0, Ticket='21440', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=223, PassengerId=224, Survived=0, Pclass=3, Name='Nenkoff, Mr. Christo', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='349234', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=224, PassengerId=225, Survived=1, Pclass=1, Name='Hoyt, Mr. Frederick Maxfield', Sex='male', Age=38.0, SibSp=1, Parch=0, Ticket='19943', Fare=90.0, Cabin='C93', Embarked='S')
# Pandas(Index=225, PassengerId=226, Survived=0, Pclass=3, Name='Berglund, Mr. Karl Ivar Sven', Sex='male', Age=22.0, SibSp=0, Parch=0, Ticket='PP 4348', Fare=9.35, Cabin=nan, Embarked='S')
# Pandas(Index=226, PassengerId=227, Survived=1, Pclass=2, Name='Mellors, Mr. William John', Sex='male', Age=19.0, SibSp=0, Parch=0, Ticket='SW/PP 751', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=227, PassengerId=228, Survived=0, Pclass=3, Name='Lovell, Mr. John Hall ("Henry")', Sex='male', Age=20.5, SibSp=0, Parch=0, Ticket='A/5 21173', Fare=7.25, Cabin=nan, Embarked='S')
# Pandas(Index=228, PassengerId=229, Survived=0, Pclass=2, Name='Fahlstrom, Mr. Arne Jonas', Sex='male', Age=18.0, SibSp=0, Parch=0, Ticket='236171', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=229, PassengerId=230, Survived=0, Pclass=3, Name='Lefebre, Miss. Mathilde', Sex='female', Age=nan, SibSp=3, Parch=1, Ticket='4133', Fare=25.4667, Cabin=nan, Embarked='S')
# Pandas(Index=230, PassengerId=231, Survived=1, Pclass=1, Name='Harris, Mrs. Henry Birkhardt (Irene Wallach)', Sex='female', Age=35.0, SibSp=1, Parch=0, Ticket='36973', Fare=83.475, Cabin='C83', Embarked='S')
# Pandas(Index=231, PassengerId=232, Survived=0, Pclass=3, Name='Larsson, Mr. Bengt Edvin', Sex='male', Age=29.0, SibSp=0, Parch=0, Ticket='347067', Fare=7.775, Cabin=nan, Embarked='S')
# Pandas(Index=232, PassengerId=233, Survived=0, Pclass=2, Name='Sjostedt, Mr. Ernst Adolf', Sex='male', Age=59.0, SibSp=0, Parch=0, Ticket='237442', Fare=13.5, Cabin=nan, Embarked='S')
# Pandas(Index=233, PassengerId=234, Survived=1, Pclass=3, Name='Asplund, Miss. Lillian Gertrud', Sex='female', Age=5.0, SibSp=4, Parch=2, Ticket='347077', Fare=31.3875, Cabin=nan, Embarked='S')
# Pandas(Index=234, PassengerId=235, Survived=0, Pclass=2, Name='Leyson, Mr. Robert William Norman', Sex='male', Age=24.0, SibSp=0, Parch=0, Ticket='C.A. 29566', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=235, PassengerId=236, Survived=0, Pclass=3, Name='Harknett, Miss. Alice Phoebe', Sex='female', Age=nan, SibSp=0, Parch=0, Ticket='W./C. 6609', Fare=7.55, Cabin=nan, Embarked='S')
# Pandas(Index=236, PassengerId=237, Survived=0, Pclass=2, Name='Hold, Mr. Stephen', Sex='male', Age=44.0, SibSp=1, Parch=0, Ticket='26707', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=237, PassengerId=238, Survived=1, Pclass=2, Name='Collyer, Miss. Marjorie "Lottie"', Sex='female', Age=8.0, SibSp=0, Parch=2, Ticket='C.A. 31921', Fare=26.25, Cabin=nan, Embarked='S')
# Pandas(Index=238, PassengerId=239, Survived=0, Pclass=2, Name='Pengelly, Mr. Frederick William', Sex='male', Age=19.0, SibSp=0, Parch=0, Ticket='28665', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=239, PassengerId=240, Survived=0, Pclass=2, Name='Hunt, Mr. George Henry', Sex='male', Age=33.0, SibSp=0, Parch=0, Ticket='SCO/W 1585', Fare=12.275, Cabin=nan, Embarked='S')
# Pandas(Index=240, PassengerId=241, Survived=0, Pclass=3, Name='Zabour, Miss. Thamine', Sex='female', Age=nan, SibSp=1, Parch=0, Ticket='2665', Fare=14.4542, Cabin=nan, Embarked='C')
# Pandas(Index=241, PassengerId=242, Survived=1, Pclass=3, Name='Murphy, Miss. Katherine "Kate"', Sex='female', Age=nan, SibSp=1, Parch=0, Ticket='367230', Fare=15.5, Cabin=nan, Embarked='Q')
# Pandas(Index=242, PassengerId=243, Survived=0, Pclass=2, Name='Coleridge, Mr. Reginald Charles', Sex='male', Age=29.0, SibSp=0, Parch=0, Ticket='W./C. 14263', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=243, PassengerId=244, Survived=0, Pclass=3, Name='Maenpaa, Mr. Matti Alexanteri', Sex='male', Age=22.0, SibSp=0, Parch=0, Ticket='STON/O 2. 3101275', Fare=7.125, Cabin=nan, Embarked='S')
# Pandas(Index=244, PassengerId=245, Survived=0, Pclass=3, Name='Attalah, Mr. Sleiman', Sex='male', Age=30.0, SibSp=0, Parch=0, Ticket='2694', Fare=7.225, Cabin=nan, Embarked='C')
# Pandas(Index=245, PassengerId=246, Survived=0, Pclass=1, Name='Minahan, Dr. William Edward', Sex='male', Age=44.0, SibSp=2, Parch=0, Ticket='19928', Fare=90.0, Cabin='C78', Embarked='Q')
# Pandas(Index=246, PassengerId=247, Survived=0, Pclass=3, Name='Lindahl, Miss. Agda Thorilda Viktoria', Sex='female', Age=25.0, SibSp=0, Parch=0, Ticket='347071', Fare=7.775, Cabin=nan, Embarked='S')
# Pandas(Index=247, PassengerId=248, Survived=1, Pclass=2, Name='Hamalainen, Mrs. William (Anna)', Sex='female', Age=24.0, SibSp=0, Parch=2, Ticket='250649', Fare=14.5, Cabin=nan, Embarked='S')
# Pandas(Index=248, PassengerId=249, Survived=1, Pclass=1, Name='Beckwith, Mr. Richard Leonard', Sex='male', Age=37.0, SibSp=1, Parch=1, Ticket='11751', Fare=52.5542, Cabin='D35', Embarked='S')
# Pandas(Index=249, PassengerId=250, Survived=0, Pclass=2, Name='Carter, Rev. Ernest Courtenay', Sex='male', Age=54.0, SibSp=1, Parch=0, Ticket='244252', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=250, PassengerId=251, Survived=0, Pclass=3, Name='Reed, Mr. James George', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='362316', Fare=7.25, Cabin=nan, Embarked='S')
# Pandas(Index=251, PassengerId=252, Survived=0, Pclass=3, Name='Strom, Mrs. Wilhelm (Elna Matilda Persson)', Sex='female', Age=29.0, SibSp=1, Parch=1, Ticket='347054', Fare=10.4625, Cabin='G6', Embarked='S')
# Pandas(Index=252, PassengerId=253, Survived=0, Pclass=1, Name='Stead, Mr. William Thomas', Sex='male', Age=62.0, SibSp=0, Parch=0, Ticket='113514', Fare=26.55, Cabin='C87', Embarked='S')
# Pandas(Index=253, PassengerId=254, Survived=0, Pclass=3, Name='Lobb, Mr. William Arthur', Sex='male', Age=30.0, SibSp=1, Parch=0, Ticket='A/5. 3336', Fare=16.1, Cabin=nan, Embarked='S')
# ...
# Pandas(Index=807, PassengerId=808, Survived=0, Pclass=3, Name='Pettersson, Miss. Ellen Natalia', Sex='female', Age=18.0, SibSp=0, Parch=0, Ticket='347087', Fare=7.775, Cabin=nan, Embarked='S')
# Pandas(Index=808, PassengerId=809, Survived=0, Pclass=2, Name='Meyer, Mr. August', Sex='male', Age=39.0, SibSp=0, Parch=0, Ticket='248723', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=809, PassengerId=810, Survived=1, Pclass=1, Name='Chambers, Mrs. Norman Campbell (Bertha Griggs)', Sex='female', Age=33.0, SibSp=1, Parch=0, Ticket='113806', Fare=53.1, Cabin='E8', Embarked='S')
# Pandas(Index=810, PassengerId=811, Survived=0, Pclass=3, Name='Alexander, Mr. William', Sex='male', Age=26.0, SibSp=0, Parch=0, Ticket='3474', Fare=7.8875, Cabin=nan, Embarked='S')
# Pandas(Index=811, PassengerId=812, Survived=0, Pclass=3, Name='Lester, Mr. James', Sex='male', Age=39.0, SibSp=0, Parch=0, Ticket='A/4 48871', Fare=24.15, Cabin=nan, Embarked='S')
# Pandas(Index=812, PassengerId=813, Survived=0, Pclass=2, Name='Slemen, Mr. Richard James', Sex='male', Age=35.0, SibSp=0, Parch=0, Ticket='28206', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=813, PassengerId=814, Survived=0, Pclass=3, Name='Andersson, Miss. Ebba Iris Alfrida', Sex='female', Age=6.0, SibSp=4, Parch=2, Ticket='347082', Fare=31.275, Cabin=nan, Embarked='S')
# Pandas(Index=814, PassengerId=815, Survived=0, Pclass=3, Name='Tomlin, Mr. Ernest Portage', Sex='male', Age=30.5, SibSp=0, Parch=0, Ticket='364499', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=815, PassengerId=816, Survived=0, Pclass=1, Name='Fry, Mr. Richard', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='112058', Fare=0.0, Cabin='B102', Embarked='S')
# Pandas(Index=816, PassengerId=817, Survived=0, Pclass=3, Name='Heininen, Miss. Wendla Maria', Sex='female', Age=23.0, SibSp=0, Parch=0, Ticket='STON/O2. 3101290', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=817, PassengerId=818, Survived=0, Pclass=2, Name='Mallet, Mr. Albert', Sex='male', Age=31.0, SibSp=1, Parch=1, Ticket='S.C./PARIS 2079', Fare=37.0042, Cabin=nan, Embarked='C')
# Pandas(Index=818, PassengerId=819, Survived=0, Pclass=3, Name='Holm, Mr. John Fredrik Alexander', Sex='male', Age=43.0, SibSp=0, Parch=0, Ticket='C 7075', Fare=6.45, Cabin=nan, Embarked='S')
# Pandas(Index=819, PassengerId=820, Survived=0, Pclass=3, Name='Skoog, Master. Karl Thorsten', Sex='male', Age=10.0, SibSp=3, Parch=2, Ticket='347088', Fare=27.9, Cabin=nan, Embarked='S')
# Pandas(Index=820, PassengerId=821, Survived=1, Pclass=1, Name='Hays, Mrs. Charles Melville (Clara Jennings Gregg)', Sex='female', Age=52.0, SibSp=1, Parch=1, Ticket='12749', Fare=93.5, Cabin='B69', Embarked='S')
# Pandas(Index=821, PassengerId=822, Survived=1, Pclass=3, Name='Lulic, Mr. Nikola', Sex='male', Age=27.0, SibSp=0, Parch=0, Ticket='315098', Fare=8.6625, Cabin=nan, Embarked='S')
# Pandas(Index=822, PassengerId=823, Survived=0, Pclass=1, Name='Reuchlin, Jonkheer. John George', Sex='male', Age=38.0, SibSp=0, Parch=0, Ticket='19972', Fare=0.0, Cabin=nan, Embarked='S')
# Pandas(Index=823, PassengerId=824, Survived=1, Pclass=3, Name='Moor, Mrs. (Beila)', Sex='female', Age=27.0, SibSp=0, Parch=1, Ticket='392096', Fare=12.475, Cabin='E121', Embarked='S')
# Pandas(Index=824, PassengerId=825, Survived=0, Pclass=3, Name='Panula, Master. Urho Abraham', Sex='male', Age=2.0, SibSp=4, Parch=1, Ticket='3101295', Fare=39.6875, Cabin=nan, Embarked='S')
# Pandas(Index=825, PassengerId=826, Survived=0, Pclass=3, Name='Flynn, Mr. John', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='368323', Fare=6.95, Cabin=nan, Embarked='Q')
# Pandas(Index=826, PassengerId=827, Survived=0, Pclass=3, Name='Lam, Mr. Len', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='1601', Fare=56.4958, Cabin=nan, Embarked='S')
# Pandas(Index=827, PassengerId=828, Survived=1, Pclass=2, Name='Mallet, Master. Andre', Sex='male', Age=1.0, SibSp=0, Parch=2, Ticket='S.C./PARIS 2079', Fare=37.0042, Cabin=nan, Embarked='C')
# Pandas(Index=828, PassengerId=829, Survived=1, Pclass=3, Name='McCormack, Mr. Thomas Joseph', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='367228', Fare=7.75, Cabin=nan, Embarked='Q')
# Pandas(Index=829, PassengerId=830, Survived=1, Pclass=1, Name='Stone, Mrs. George Nelson (Martha Evelyn)', Sex='female', Age=62.0, SibSp=0, Parch=0, Ticket='113572', Fare=80.0, Cabin='B28', Embarked=nan)
# Pandas(Index=830, PassengerId=831, Survived=1, Pclass=3, Name='Yasbeck, Mrs. Antoni (Selini Alexander)', Sex='female', Age=15.0, SibSp=1, Parch=0, Ticket='2659', Fare=14.4542, Cabin=nan, Embarked='C')
# Pandas(Index=831, PassengerId=832, Survived=1, Pclass=2, Name='Richards, Master. George Sibley', Sex='male', Age=0.83, SibSp=1, Parch=1, Ticket='29106', Fare=18.75, Cabin=nan, Embarked='S')
# Pandas(Index=832, PassengerId=833, Survived=0, Pclass=3, Name='Saad, Mr. Amin', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='2671', Fare=7.2292, Cabin=nan, Embarked='C')
# Pandas(Index=833, PassengerId=834, Survived=0, Pclass=3, Name='Augustsson, Mr. Albert', Sex='male', Age=23.0, SibSp=0, Parch=0, Ticket='347468', Fare=7.8542, Cabin=nan, Embarked='S')
# Pandas(Index=834, PassengerId=835, Survived=0, Pclass=3, Name='Allum, Mr. Owen George', Sex='male', Age=18.0, SibSp=0, Parch=0, Ticket='2223', Fare=8.3, Cabin=nan, Embarked='S')
# Pandas(Index=835, PassengerId=836, Survived=1, Pclass=1, Name='Compton, Miss. Sara Rebecca', Sex='female', Age=39.0, SibSp=1, Parch=1, Ticket='PC 17756', Fare=83.1583, Cabin='E49', Embarked='C')
# Pandas(Index=836, PassengerId=837, Survived=0, Pclass=3, Name='Pasic, Mr. Jakob', Sex='male', Age=21.0, SibSp=0, Parch=0, Ticket='315097', Fare=8.6625, Cabin=nan, Embarked='S')
# Pandas(Index=837, PassengerId=838, Survived=0, Pclass=3, Name='Sirota, Mr. Maurice', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='392092', Fare=8.05, Cabin=nan, Embarked='S')
# Pandas(Index=838, PassengerId=839, Survived=1, Pclass=3, Name='Chip, Mr. Chang', Sex='male', Age=32.0, SibSp=0, Parch=0, Ticket='1601', Fare=56.4958, Cabin=nan, Embarked='S')
# Pandas(Index=839, PassengerId=840, Survived=1, Pclass=1, Name='Marechal, Mr. Pierre', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='11774', Fare=29.7, Cabin='C47', Embarked='C')
# Pandas(Index=840, PassengerId=841, Survived=0, Pclass=3, Name='Alhomaki, Mr. Ilmari Rudolf', Sex='male', Age=20.0, SibSp=0, Parch=0, Ticket='SOTON/O2 3101287', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=841, PassengerId=842, Survived=0, Pclass=2, Name='Mudd, Mr. Thomas Charles', Sex='male', Age=16.0, SibSp=0, Parch=0, Ticket='S.O./P.P. 3', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=842, PassengerId=843, Survived=1, Pclass=1, Name='Serepeca, Miss. Augusta', Sex='female', Age=30.0, SibSp=0, Parch=0, Ticket='113798', Fare=31.0, Cabin=nan, Embarked='C')
# Pandas(Index=843, PassengerId=844, Survived=0, Pclass=3, Name='Lemberopolous, Mr. Peter L', Sex='male', Age=34.5, SibSp=0, Parch=0, Ticket='2683', Fare=6.4375, Cabin=nan, Embarked='C')
# Pandas(Index=844, PassengerId=845, Survived=0, Pclass=3, Name='Culumovic, Mr. Jeso', Sex='male', Age=17.0, SibSp=0, Parch=0, Ticket='315090', Fare=8.6625, Cabin=nan, Embarked='S')
# Pandas(Index=845, PassengerId=846, Survived=0, Pclass=3, Name='Abbing, Mr. Anthony', Sex='male', Age=42.0, SibSp=0, Parch=0, Ticket='C.A. 5547', Fare=7.55, Cabin=nan, Embarked='S')
# Pandas(Index=846, PassengerId=847, Survived=0, Pclass=3, Name='Sage, Mr. Douglas Bullen', Sex='male', Age=nan, SibSp=8, Parch=2, Ticket='CA. 2343', Fare=69.55, Cabin=nan, Embarked='S')
# Pandas(Index=847, PassengerId=848, Survived=0, Pclass=3, Name='Markoff, Mr. Marin', Sex='male', Age=35.0, SibSp=0, Parch=0, Ticket='349213', Fare=7.8958, Cabin=nan, Embarked='C')
# Pandas(Index=848, PassengerId=849, Survived=0, Pclass=2, Name='Harper, Rev. John', Sex='male', Age=28.0, SibSp=0, Parch=1, Ticket='248727', Fare=33.0, Cabin=nan, Embarked='S')
# Pandas(Index=849, PassengerId=850, Survived=1, Pclass=1, Name='Goldenberg, Mrs. Samuel L (Edwiga Grabowska)', Sex='female', Age=nan, SibSp=1, Parch=0, Ticket='17453', Fare=89.1042, Cabin='C92', Embarked='C')
# Pandas(Index=850, PassengerId=851, Survived=0, Pclass=3, Name='Andersson, Master. Sigvard Harald Elias', Sex='male', Age=4.0, SibSp=4, Parch=2, Ticket='347082', Fare=31.275, Cabin=nan, Embarked='S')
# Pandas(Index=851, PassengerId=852, Survived=0, Pclass=3, Name='Svensson, Mr. Johan', Sex='male', Age=74.0, SibSp=0, Parch=0, Ticket='347060', Fare=7.775, Cabin=nan, Embarked='S')
# Pandas(Index=852, PassengerId=853, Survived=0, Pclass=3, Name='Boulos, Miss. Nourelain', Sex='female', Age=9.0, SibSp=1, Parch=1, Ticket='2678', Fare=15.2458, Cabin=nan, Embarked='C')
# Pandas(Index=853, PassengerId=854, Survived=1, Pclass=1, Name='Lines, Miss. Mary Conover', Sex='female', Age=16.0, SibSp=0, Parch=1, Ticket='PC 17592', Fare=39.4, Cabin='D28', Embarked='S')
# Pandas(Index=854, PassengerId=855, Survived=0, Pclass=2, Name='Carter, Mrs. Ernest Courtenay (Lilian Hughes)', Sex='female', Age=44.0, SibSp=1, Parch=0, Ticket='244252', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=855, PassengerId=856, Survived=1, Pclass=3, Name='Aks, Mrs. Sam (Leah Rosen)', Sex='female', Age=18.0, SibSp=0, Parch=1, Ticket='392091', Fare=9.35, Cabin=nan, Embarked='S')
# Pandas(Index=856, PassengerId=857, Survived=1, Pclass=1, Name='Wick, Mrs. George Dennick (Mary Hitchcock)', Sex='female', Age=45.0, SibSp=1, Parch=1, Ticket='36928', Fare=164.8667, Cabin=nan, Embarked='S')
# Pandas(Index=857, PassengerId=858, Survived=1, Pclass=1, Name='Daly, Mr. Peter Denis ', Sex='male', Age=51.0, SibSp=0, Parch=0, Ticket='113055', Fare=26.55, Cabin='E17', Embarked='S')
# Pandas(Index=858, PassengerId=859, Survived=1, Pclass=3, Name='Baclini, Mrs. Solomon (Latifa Qurban)', Sex='female', Age=24.0, SibSp=0, Parch=3, Ticket='2666', Fare=19.2583, Cabin=nan, Embarked='C')
# Pandas(Index=859, PassengerId=860, Survived=0, Pclass=3, Name='Razi, Mr. Raihed', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='2629', Fare=7.2292, Cabin=nan, Embarked='C')
# Pandas(Index=860, PassengerId=861, Survived=0, Pclass=3, Name='Hansen, Mr. Claus Peter', Sex='male', Age=41.0, SibSp=2, Parch=0, Ticket='350026', Fare=14.1083, Cabin=nan, Embarked='S')
# Pandas(Index=861, PassengerId=862, Survived=0, Pclass=2, Name='Giles, Mr. Frederick Edward', Sex='male', Age=21.0, SibSp=1, Parch=0, Ticket='28134', Fare=11.5, Cabin=nan, Embarked='S')
# Pandas(Index=862, PassengerId=863, Survived=1, Pclass=1, Name='Swift, Mrs. Frederick Joel (Margaret Welles Barron)', Sex='female', Age=48.0, SibSp=0, Parch=0, Ticket='17466', Fare=25.9292, Cabin='D17', Embarked='S')
# Pandas(Index=863, PassengerId=864, Survived=0, Pclass=3, Name='Sage, Miss. Dorothy Edith "Dolly"', Sex='female', Age=nan, SibSp=8, Parch=2, Ticket='CA. 2343', Fare=69.55, Cabin=nan, Embarked='S')
# Pandas(Index=864, PassengerId=865, Survived=0, Pclass=2, Name='Gill, Mr. John William', Sex='male', Age=24.0, SibSp=0, Parch=0, Ticket='233866', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=865, PassengerId=866, Survived=1, Pclass=2, Name='Bystrom, Mrs. (Karolina)', Sex='female', Age=42.0, SibSp=0, Parch=0, Ticket='236852', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=866, PassengerId=867, Survived=1, Pclass=2, Name='Duran y More, Miss. Asuncion', Sex='female', Age=27.0, SibSp=1, Parch=0, Ticket='SC/PARIS 2149', Fare=13.8583, Cabin=nan, Embarked='C')
# Pandas(Index=867, PassengerId=868, Survived=0, Pclass=1, Name='Roebling, Mr. Washington Augustus II', Sex='male', Age=31.0, SibSp=0, Parch=0, Ticket='PC 17590', Fare=50.4958, Cabin='A24', Embarked='S')
# Pandas(Index=868, PassengerId=869, Survived=0, Pclass=3, Name='van Melkebeke, Mr. Philemon', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='345777', Fare=9.5, Cabin=nan, Embarked='S')
# Pandas(Index=869, PassengerId=870, Survived=1, Pclass=3, Name='Johnson, Master. Harold Theodor', Sex='male', Age=4.0, SibSp=1, Parch=1, Ticket='347742', Fare=11.1333, Cabin=nan, Embarked='S')
# Pandas(Index=870, PassengerId=871, Survived=0, Pclass=3, Name='Balkic, Mr. Cerin', Sex='male', Age=26.0, SibSp=0, Parch=0, Ticket='349248', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=871, PassengerId=872, Survived=1, Pclass=1, Name='Beckwith, Mrs. Richard Leonard (Sallie Monypeny)', Sex='female', Age=47.0, SibSp=1, Parch=1, Ticket='11751', Fare=52.5542, Cabin='D35', Embarked='S')
# Pandas(Index=872, PassengerId=873, Survived=0, Pclass=1, Name='Carlsson, Mr. Frans Olof', Sex='male', Age=33.0, SibSp=0, Parch=0, Ticket='695', Fare=5.0, Cabin='B51 B53 B55', Embarked='S')
# Pandas(Index=873, PassengerId=874, Survived=0, Pclass=3, Name='Vander Cruyssen, Mr. Victor', Sex='male', Age=47.0, SibSp=0, Parch=0, Ticket='345765', Fare=9.0, Cabin=nan, Embarked='S')
# Pandas(Index=874, PassengerId=875, Survived=1, Pclass=2, Name='Abelson, Mrs. Samuel (Hannah Wizosky)', Sex='female', Age=28.0, SibSp=1, Parch=0, Ticket='P/PP 3381', Fare=24.0, Cabin=nan, Embarked='C')
# Pandas(Index=875, PassengerId=876, Survived=1, Pclass=3, Name='Najib, Miss. Adele Kiamie "Jane"', Sex='female', Age=15.0, SibSp=0, Parch=0, Ticket='2667', Fare=7.225, Cabin=nan, Embarked='C')
# Pandas(Index=876, PassengerId=877, Survived=0, Pclass=3, Name='Gustafsson, Mr. Alfred Ossian', Sex='male', Age=20.0, SibSp=0, Parch=0, Ticket='7534', Fare=9.8458, Cabin=nan, Embarked='S')
# Pandas(Index=877, PassengerId=878, Survived=0, Pclass=3, Name='Petroff, Mr. Nedelio', Sex='male', Age=19.0, SibSp=0, Parch=0, Ticket='349212', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=878, PassengerId=879, Survived=0, Pclass=3, Name='Laleff, Mr. Kristo', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='349217', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=879, PassengerId=880, Survived=1, Pclass=1, Name='Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)', Sex='female', Age=56.0, SibSp=0, Parch=1, Ticket='11767', Fare=83.1583, Cabin='C50', Embarked='C')
# Pandas(Index=880, PassengerId=881, Survived=1, Pclass=2, Name='Shelley, Mrs. William (Imanita Parrish Hall)', Sex='female', Age=25.0, SibSp=0, Parch=1, Ticket='230433', Fare=26.0, Cabin=nan, Embarked='S')
# Pandas(Index=881, PassengerId=882, Survived=0, Pclass=3, Name='Markun, Mr. Johann', Sex='male', Age=33.0, SibSp=0, Parch=0, Ticket='349257', Fare=7.8958, Cabin=nan, Embarked='S')
# Pandas(Index=882, PassengerId=883, Survived=0, Pclass=3, Name='Dahlberg, Miss. Gerda Ulrika', Sex='female', Age=22.0, SibSp=0, Parch=0, Ticket='7552', Fare=10.5167, Cabin=nan, Embarked='S')
# Pandas(Index=883, PassengerId=884, Survived=0, Pclass=2, Name='Banfield, Mr. Frederick James', Sex='male', Age=28.0, SibSp=0, Parch=0, Ticket='C.A./SOTON 34068', Fare=10.5, Cabin=nan, Embarked='S')
# Pandas(Index=884, PassengerId=885, Survived=0, Pclass=3, Name='Sutehall, Mr. Henry Jr', Sex='male', Age=25.0, SibSp=0, Parch=0, Ticket='SOTON/OQ 392076', Fare=7.05, Cabin=nan, Embarked='S')
# Pandas(Index=885, PassengerId=886, Survived=0, Pclass=3, Name='Rice, Mrs. William (Margaret Norton)', Sex='female', Age=39.0, SibSp=0, Parch=5, Ticket='382652', Fare=29.125, Cabin=nan, Embarked='Q')
# Pandas(Index=886, PassengerId=887, Survived=0, Pclass=2, Name='Montvila, Rev. Juozas', Sex='male', Age=27.0, SibSp=0, Parch=0, Ticket='211536', Fare=13.0, Cabin=nan, Embarked='S')
# Pandas(Index=887, PassengerId=888, Survived=1, Pclass=1, Name='Graham, Miss. Margaret Edith', Sex='female', Age=19.0, SibSp=0, Parch=0, Ticket='112053', Fare=30.0, Cabin='B42', Embarked='S')
# Pandas(Index=888, PassengerId=889, Survived=0, Pclass=3, Name='Johnston, Miss. Catherine Helen "Carrie"', Sex='female', Age=nan, SibSp=1, Parch=2, Ticket='W./C. 6607', Fare=23.45, Cabin=nan, Embarked='S')
# Pandas(Index=889, PassengerId=890, Survived=1, Pclass=1, Name='Behr, Mr. Karl Howell', Sex='male', Age=26.0, SibSp=0, Parch=0, Ticket='111369', Fare=30.0, Cabin='C148', Embarked='C')
# Pandas(Index=890, PassengerId=891, Survived=0, Pclass=3, Name='Dooley, Mr. Patrick', Sex='male', Age=32.0, SibSp=0, Parch=0, Ticket='370376', Fare=7.75, Cabin=nan, Embarked='Q')

# %%
for row in df.itertuples():
    print(f"name : {row.Name}  || he surived ? : {row.Survived}")
# Out:
# name : Braund, Mr. Owen Harris  || he surived ? : 0
# name : Cumings, Mrs. John Bradley (Florence Briggs Thayer)  || he surived ? : 1
# name : Heikkinen, Miss. Laina  || he surived ? : 1
# name : Futrelle, Mrs. Jacques Heath (Lily May Peel)  || he surived ? : 1
# name : Allen, Mr. William Henry  || he surived ? : 0
# name : Moran, Mr. James  || he surived ? : 0
# name : McCarthy, Mr. Timothy J  || he surived ? : 0
# name : Palsson, Master. Gosta Leonard  || he surived ? : 0
# name : Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  || he surived ? : 1
# name : Nasser, Mrs. Nicholas (Adele Achem)  || he surived ? : 1
# name : Sandstrom, Miss. Marguerite Rut  || he surived ? : 1
# name : Bonnell, Miss. Elizabeth  || he surived ? : 1
# name : Saundercock, Mr. William Henry  || he surived ? : 0
# name : Andersson, Mr. Anders Johan  || he surived ? : 0
# name : Vestrom, Miss. Hulda Amanda Adolfina  || he surived ? : 0
# name : Hewlett, Mrs. (Mary D Kingcome)   || he surived ? : 1
# name : Rice, Master. Eugene  || he surived ? : 0
# name : Williams, Mr. Charles Eugene  || he surived ? : 1
# name : Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)  || he surived ? : 0
# name : Masselmani, Mrs. Fatima  || he surived ? : 1
# name : Fynney, Mr. Joseph J  || he surived ? : 0
# name : Beesley, Mr. Lawrence  || he surived ? : 1
# name : McGowan, Miss. Anna "Annie"  || he surived ? : 1
# name : Sloper, Mr. William Thompson  || he surived ? : 1
# name : Palsson, Miss. Torborg Danira  || he surived ? : 0
# name : Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)  || he surived ? : 1
# name : Emir, Mr. Farred Chehab  || he surived ? : 0
# name : Fortune, Mr. Charles Alexander  || he surived ? : 0
# name : O'Dwyer, Miss. Ellen "Nellie"  || he surived ? : 1
# name : Todoroff, Mr. Lalio  || he surived ? : 0
# name : Uruchurtu, Don. Manuel E  || he surived ? : 0
# name : Spencer, Mrs. William Augustus (Marie Eugenie)  || he surived ? : 1
# name : Glynn, Miss. Mary Agatha  || he surived ? : 1
# name : Wheadon, Mr. Edward H  || he surived ? : 0
# name : Meyer, Mr. Edgar Joseph  || he surived ? : 0
# name : Holverson, Mr. Alexander Oskar  || he surived ? : 0
# name : Mamee, Mr. Hanna  || he surived ? : 1
# name : Cann, Mr. Ernest Charles  || he surived ? : 0
# name : Vander Planke, Miss. Augusta Maria  || he surived ? : 0
# name : Nicola-Yarred, Miss. Jamila  || he surived ? : 1
# name : Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  || he surived ? : 0
# name : Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott
hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)  || he surived ? : 1
# name : Burke, Mr. Jeremiah  || he surived ? : 0
# name : Andrew, Mr. Edgardo Samuel  || he surived ? : 0
# name : Nicholls, Mr. Joseph Charles  || he surived ? : 0
# name : Andersson, Mr. August Edvard ("Wennerstrom")  || he surived ? : 1
# name : Ford, Miss. Robina Maggie "Ruby"  || he surived ? : 0
# name : Navratil, Mr. Michel ("Louis M Hoffman")  || he surived ? : 0
# name : Byles, Rev. Thomas Roussel Davids  || he surived ? : 0
# name : Bateman, Rev. Robert James  || he surived ? : 0
# name : Pears, Mrs. Thomas (Edith Wearne)  || he surived ? : 1
# name : Meo, Mr. Alfonzo  || he surived ? : 0
# name : van Billiard, Mr. Austin Blyler  || he surived ? : 0
# name : Olsen, Mr. Ole Martin  || he surived ? : 0
# name : Williams, Mr. Charles Duane  || he surived ? : 0
# name : Gilnagh, Miss. Katherine "Katie"  || he surived ? : 1
# name : Corn, Mr. Harry  || he surived ? : 0
# name : Smiljanic, Mr. Mile  || he surived ? : 0
# name : Sage, Master. Thomas Henry  || he surived ? : 0
# name : Cribb, Mr. John Hatfield  || he surived ? : 0
# name : Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)  || he surived ? : 1
# name : Bengtsson, Mr. John Viktor  || he surived ? : 0
# name : Calic, Mr. Jovo  || he surived ? : 0
# name : Panula, Master. Eino Viljami  || he surived ? : 0
# name : Goldsmith, Master. Frank John William "Frankie"  || he surived ? : 1
# name : Chibnall, Mrs. (Edith Martha Bowerman)  || he surived ? : 1
# name : Skoog, Mrs. William (Anna Bernhardina Karlsson)  || he surived ? : 0
# name : Baumann, Mr. John D  || he surived ? : 0
# name : Ling, Mr. Lee  || he surived ? : 0
# name : Van der hoef, Mr. Wyckoff  || he surived ? : 0
# name : Rice, Master. Arthur  || he surived ? : 0
# name : Johnson, Miss. Eleanor Ileen  || he surived ? : 1
# name : Sivola, Mr. Antti Wilhelm  || he surived ? : 0
# name : Smith, Mr. James Clinch  || he surived ? : 0
# name : Klasen, Mr. Klas Albin  || he surived ? : 0
# name : Lefebre, Master. Henry Forbes  || he surived ? : 0
# name : Isham, Miss. Ann Elizabeth  || he surived ? : 0
# name : Hale, Mr. Reginald  || he surived ? : 0
# name : Leonard, Mr. Lionel  || he surived ? : 0
# name : Sage, Miss. Constance Gladys  || he surived ? : 0
# name : Pernot, Mr. Rene  || he surived ? : 0
# name : Asplund, Master. Clarence Gustaf Hugo  || he surived ? : 0
# name : Becker, Master. Richard F  || he surived ? : 1
# name : Kink-Heilmann, Miss. Luise Gretchen  || he surived ? : 1
# name : Rood, Mr. Hugh Roscoe  || he surived ? : 0
# name : O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  || he surived ? : 1
# name : Romaine, Mr. Charles Hallace ("Mr C Rolmane")  || he surived ? : 1
# name : Bourke, Mr. John  || he surived ? : 0
# name : Turcin, Mr. Stjepan  || he surived ? : 0
# name : Pinsky, Mrs. (Rosa)  || he surived ? : 1
# name : Carbines, Mr. William  || he surived ? : 0
# name : Andersen-Jensen, Miss. Carla Christine Nielsine  || he surived ? : 1
# name : Navratil, Master. Michel M  || he surived ? : 1
# name : Brown, Mrs. James Joseph (Margaret Tobin)  || he surived ? : 1
# name : Lurette, Miss. Elise  || he surived ? : 1
# name : Mernagh, Mr. Robert  || he surived ? : 0
# name : Olsen, Mr. Karl Siegwart Andreas  || he surived ? : 0
# name : Madigan, Miss. Margaret "Maggie"  || he surived ? : 1
# name : Yrois, Miss. Henriette ("Mrs Harbeck")  || he surived ? : 0
# name : Arnold-Franchi, Mr. Josef  || he surived ? : 0
# name : Yousif, Mr. Wazli  || he surived ? : 0
# name : Vanden Steen, Mr. Leo Peter  || he surived ? : 0
# name : Bowerman, Miss. Elsie Edith  || he surived ? : 1
# name : Funk, Miss. Annie Clemmer  || he surived ? : 0
# name : McGovern, Miss. Mary  || he surived ? : 1
# name : Mockler, Miss. Helen Mary "Ellie"  || he surived ? : 1
# name : Skoog, Mr. Wilhelm  || he surived ? : 0
# name : del Carlo, Mr. Sebastiano  || he surived ? : 0
# name : Barbara, Mrs. (Catherine David)  || he surived ? : 0
# name : Asim, Mr. Adola  || he surived ? : 0
# name : O'Brien, Mr. Thomas  || he surived ? : 0
# name : Adahl, Mr. Mauritz Nils Martin  || he surived ? : 0
# name : Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  || he surived ? : 1
# name : Moussa, Mrs. (Mantoura Boulos)  || he surived ? : 1
# name : Jermyn, Miss. Annie  || he surived ? : 1
# name : Aubart, Mme. Leontine Pauline  || he surived ? : 1
# name : Harder, Mr. George Achilles  || he surived ? : 1
# name : Wiklund, Mr. Jakob Alfred  || he surived ? : 0
# name : Beavan, Mr. William Thomas  || he surived ? : 0
# name : Ringhini, Mr. Sante  || he surived ? : 0
# name : Palsson, Miss. Stina Viola  || he surived ? : 0
# name : Meyer, Mrs. Edgar Joseph (Leila Saks)  || he surived ? : 1
# name : Landergren, Miss. Aurora Adelia  || he surived ? : 1
# name : Widener, Mr. Harry Elkins  || he surived ? : 0
# name : Betros, Mr. Tannous  || he surived ? : 0
# name : Gustafsson, Mr. Karl Gideon  || he surived ? : 0
# name : Bidois, Miss. Rosalie  || he surived ? : 1
# name : Nakid, Miss. Maria ("Mary")  || he surived ? : 1
# name : Tikkanen, Mr. Juho  || he surived ? : 0
# name : Holverson, Mrs. Alexander Oskar (Mary Aline Towner)  || he surived ? : 1
# name : Plotcharsky, Mr. Vasil  || he surived ? : 0
# name : Davies, Mr. Charles Henry  || he surived ? : 0
# name : Goodwin, Master. Sidney Leonard  || he surived ? : 0
# name : Buss, Miss. Kate  || he surived ? : 1
# name : Sadlier, Mr. Matthew  || he surived ? : 0
# name : Lehmann, Miss. Bertha  || he surived ? : 1
# name : Carter, Mr. William Ernest  || he surived ? : 1
# name : Jansson, Mr. Carl Olof  || he surived ? : 1
# name : Gustafsson, Mr. Johan Birger  || he surived ? : 0
# name : Newell, Miss. Marjorie  || he surived ? : 1
# name : Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)  || he surived ? : 1
# name : Johansson, Mr. Erik  || he surived ? : 0
# name : Olsson, Miss. Elina  || he surived ? : 0
# name : McKane, Mr. Peter David  || he surived ? : 0
# name : Pain, Dr. Alfred  || he surived ? : 0
# name : Trout, Mrs. William H (Jessie L)  || he surived ? : 1
# name : Niskanen, Mr. Juha  || he surived ? : 1
# name : Adams, Mr. John  || he surived ? : 0
# name : Jussila, Miss. Mari Aina  || he surived ? : 0
# name : Hakkarainen, Mr. Pekka Pietari  || he surived ? : 0
# name : Oreskovic, Miss. Marija  || he surived ? : 0
# name : Gale, Mr. Shadrach  || he surived ? : 0
# name : Tomlin, Mr. Ernest Portage  || he surived ? : 0
# name : Fry, Mr. Richard  || he surived ? : 0
# name : Heininen, Miss. Wendla Maria  || he surived ? : 0
# name : Mallet, Mr. Albert  || he surived ? : 0
# name : Holm, Mr. John Fredrik Alexander  || he surived ? : 0
# name : Skoog, Master. Karl Thorsten  || he surived ? : 0
# name : Hays, Mrs. Charles Melville (Clara Jennings Gregg)  || he surived ? : 1
# name : Lulic, Mr. Nikola  || he surived ? : 1
# name : Reuchlin, Jonkheer. John George  || he surived ? : 0
# name : Moor, Mrs. (Beila)  || he surived ? : 1
# name : Panula, Master. Urho Abraham  || he surived ? : 0
# name : Flynn, Mr. John  || he surived ? : 0
# name : Lam, Mr. Len  || he surived ? : 0
# name : Mallet, Master. Andre  || he surived ? : 1
# name : McCormack, Mr. Thomas Joseph  || he surived ? : 1
# name : Stone, Mrs. George Nelson (Martha Evelyn)  || he surived ? : 1
# name : Yasbeck, Mrs. Antoni (Selini Alexander)  || he surived ? : 1
# name : Richards, Master. George Sibley  || he surived ? : 1
# name : Saad, Mr. Amin  || he surived ? : 0
# name : Augustsson, Mr. Albert  || he surived ? : 0
# name : Allum, Mr. Owen George  || he surived ? : 0
# name : Compton, Miss. Sara Rebecca  || he surived ? : 1
# name : Pasic, Mr. Jakob  || he surived ? : 0
# name : Sirota, Mr. Maurice  || he surived ? : 0
# name : Chip, Mr. Chang  || he surived ? : 1
# name : Marechal, Mr. Pierre  || he surived ? : 1
# name : Alhomaki, Mr. Ilmari Rudolf  || he surived ? : 0
# name : Mudd, Mr. Thomas Charles  || he surived ? : 0
# name : Serepeca, Miss. Augusta  || he surived ? : 1
# name : Lemberopolous, Mr. Peter L  || he surived ? : 0
# name : Culumovic, Mr. Jeso  || he surived ? : 0
# name : Abbing, Mr. Anthony  || he surived ? : 0
# name : Sage, Mr. Douglas Bullen  || he surived ? : 0
# name : Markoff, Mr. Marin  || he surived ? : 0
# name : Harper, Rev. John  || he surived ? : 0
# name : Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  || he surived ? : 1
# name : Andersson, Master. Sigvard Harald Elias  || he surived ? : 0
# name : Svensson, Mr. Johan  || he surived ? : 0
# name : Boulos, Miss. Nourelain  || he surived ? : 0
# name : Lines, Miss. Mary Conover  || he surived ? : 1
# name : Carter, Mrs. Ernest Courtenay (Lilian Hughes)  || he surived ? : 0
# name : Aks, Mrs. Sam (Leah Rosen)  || he surived ? : 1
# name : Wick, Mrs. George Dennick (Mary Hitchcock)  || he surived ? : 1
# name : Daly, Mr. Peter Denis   || he surived ? : 1
# name : Baclini, Mrs. Solomon (Latifa Qurban)  || he surived ? : 1
# name : Razi, Mr. Raihed  || he surived ? : 0
# name : Hansen, Mr. Claus Peter  || he surived ? : 0
# name : Giles, Mr. Frederick Edward  || he surived ? : 0
# name : Swift, Mrs. Frederick Joel (Margaret Welles Barron)  || he surived ? : 1
# name : Sage, Miss. Dorothy Edith "Dolly"  || he surived ? : 0
# name : Gill, Mr. John William  || he surived ? : 0
# name : Bystrom, Mrs. (Karolina)  || he surived ? : 1
# name : Duran y More, Miss. Asuncion  || he surived ? : 1
# name : Roebling, Mr. Washington Augustus II  || he surived ? : 0
# name : van Melkebeke, Mr. Philemon  || he surived ? : 0
# name : Johnson, Master. Harold Theodor  || he surived ? : 1
# name : Balkic, Mr. Cerin  || he surived ? : 0
# name : Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  || he surived ? : 1
# name : Carlsson, Mr. Frans Olof  || he surived ? : 0
# name : Vander Cruyssen, Mr. Victor  || he surived ? : 0
# name : Abelson, Mrs. Samuel (Hannah Wizosky)  || he surived ? : 1
# name : Najib, Miss. Adele Kiamie "Jane"  || he surived ? : 1
# name : Gustafsson, Mr. Alfred Ossian  || he surived ? : 0
# name : Petroff, Mr. Nedelio  || he surived ? : 0
# name : Laleff, Mr. Kristo  || he surived ? : 0
# name : Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  || he surived ? : 1
# name : Shelley, Mrs. William (Imanita Parrish Hall)  || he surived ? : 1
# name : Markun, Mr. Johann  || he surived ? : 0
# name : Dahlberg, Miss. Gerda Ulrika  || he surived ? : 0
# name : Banfield, Mr. Frederick James  || he surived ? : 0
# name : Sutehall, Mr. Henry Jr  || he surived ? : 0
# name : Rice, Mrs. William (Margaret Norton)  || he surived ? : 0
# name : Montvila, Rev. Juozas  || he surived ? : 0
# name : Graham, Miss. Margaret Edith  || he surived ? : 1
# name : Johnston, Miss. Catherine Helen "Carrie"  || he surived ? : 0
# name : Behr, Mr. Karl Howell  || he surived ? : 1
# name : Dooley, Mr. Patrick  || he surived ? : 0

# %%
# preview of the dataframe
df.head(7) # by default if we dont mention - its 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S

# %%
df.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# 887  female  19.0      0      0           112053  30.000   B42        S
# 888  female   NaN      1      2       W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0           111369  30.000  C148        C
# 890    male  32.0      0      0           370376   7.750   NaN        Q

# %%
print(df.tail())
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.loc[0] # first row
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.loc[0, 'Name'] # name of the passenger at index 0
# df['Name'][0] # can also be done like this
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df.loc[0:4] # shows rows data from 0 to 4(inclusive)
# df.loc[0:4,"Name"] # shows names from 0 to 4(inclusive)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0] # 1st row
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[0:4] # exclusive of the end index
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.iloc[0, 3] # position index
# Out:
# 'Braund, Mr. Owen Harris'

# %% [markdown]
# # Conditional selection

# %%
# df[condition]
older_passengers = df[df['Age'] > 70] # get all the rows where person age is greater than 70
older_passengers.head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
# get all the females who surivived
df[(df['Sex'] == 'female') & df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [233 rows x 12 columns]

# %%
# get all the females who surivived
female_surviors_subset = df[(df['Sex'] == 'female') & df['Survived'] == 1][['Name', 'Age']]
female_surviors_subset.head()
# Out:
#                                                 Name   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
# total number of survivors

survived = len(df[df['Survived'] == 1])
notsurvived = len(df[df['Survived'] == 0])
print(f"people who have not survived {notsurvived}")
print(f"people who have survived {survived}")
print(notsurvived + survived)
# Out:
# people who have not survived 549
# people who have survived 342
# 891

# %%
female_survivors_subset_loc = df.loc[(df['Sex'] == 'female') & (df['Survived'] == 1), ['Name', 'Age']]
female_survivors_subset_loc.head()
# Out:
#                                                 Name   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
female_survivors_subset_loc = df[(df['Sex'] == 'female') & (df['Survived'] == 1)][['Name', 'Age']]
female_survivors_subset_loc.head()
# Out:
#                                                 Name   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %% [markdown]
# # Slicing Rows and Columns

# %%
df.loc[0:4,  ['Name', 'Age']]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
# I want first 3 rows and first 2 columns

df.iloc[0:3, 0:2]
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1

# %%
# First 3 rows and selected columns by index
# --> column 1,3

df.iloc[0:3, [1, 3]]
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1                             Heikkinen, Miss. Laina

# %%
df.loc[0:2, ['Name', 'Survived']]
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1

# %%
subset = df[df['Sex'] == 'male'] # might create a view  # filtered rows where 'Sex' is male
subset['Age'] = subset['Age'] + 1  # trying to increment Age by 1

print(subset.head(2))
print(df.head(2))

# Warning You Might See: SettingWithCopyWarning:
# Pandas doesn't know for sure whether you're modifying: the original df, or copy subset
# may return either: A view (shared memory),or a copy (separate memory)

# Correct Way (safe and recommended): Use .copy() to explicitly make a copy
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 0            1         0       3   Braund, Mr. Owen Harris  male  23.0      1
# 4            5         0       3  Allen, Mr. William Henry  male  36.0      0
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
# 4      0     373450  8.05   NaN        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# C:\Users\nikunj.dhaka\AppData\Local\Temp\ipykernel_18376\739299499.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Age'] = subset['Age'] + 1  # trying to increment Age by 1

# %%
subset = df[df['Sex'] == 'male'].copy()
subset['Age'] += 1
print(subset)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    23.0      1      0         A/5 21171   7.2500   NaN        S
# 4    36.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    55.0      0      0             17463  51.8625   E46        S
# 7     3.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  29.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  26.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  28.0      0      0            211536  13.0000   NaN        S
# 889  27.0      0      0            111369  30.0000  C148        C
# 890  33.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
df_by_name = df.set_index('Name') # moves the 'Name' column into the index of the DataFrame.
df_by_name.head()

# By default, set_index() returns a new DataFrame (doesn't change df itself).

# If you want to modify in-place, use: df.set_index('Name', inplace=True)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S

# %%
print(df_by_name.loc['Allen, Mr. William Henry'])
# Out:
# PassengerId         5
# Survived            0
# Pclass              3
# Sex              male
# Age              35.0
# SibSp               0
# Parch               0
# Ticket         373450
# Fare             8.05
# Cabin             NaN
# Embarked            S
# Name: Allen, Mr. William Henry, dtype: object

# %%
# moves the index back into a regular column, and 
# restores the default integer index (0, 1, 2, ...).
# The DataFrame now has a default RangeIndex again
df_by_name = df_by_name.reset_index()
df_by_name.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_by_name.reset_index(inplace=True)
df_by_name.head()
# Out:
#    index                                               Name  PassengerId  \
# 0      0                            Braund, Mr. Owen Harris            1
# 1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2      2                             Heikkinen, Miss. Laina            3
# 3      3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 4      4                           Allen, Mr. William Henry            5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %%
df_by_name = df.set_index('Name')
df_by_name = df_by_name.reset_index()
df_by_name.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# # Reindex

# %%
sales_jan = pd.DataFrame({
    'Sales': [250, 400, 300]
}, index=['Store_A', 'Store_B', 'Store_C'])

sales_jan
# Out:
#          Sales
# Store_A    250
# Store_B    400
# Store_C    300

# %%
sales_feb = pd.DataFrame({
    'Sales': [260, 310]
}, index=['Store_A', 'Store_C'])

sales_feb
# Out:
#          Sales
# Store_A    260
# Store_C    310

# %%
common_index = sales_jan.index
sales_feb_aligned = sales_feb.reindex(common_index)
sales_feb_aligned
# Out:
#          Sales
# Store_A  260.0
# Store_B    NaN
# Store_C  310.0

# %%
sales_diff = sales_feb_aligned['Sales'] - sales_jan['Sales']
sales_diff
# Out:
# Store_A    10.0
# Store_B     NaN
# Store_C    10.0
# Name: Sales, dtype: float64

# %%
# fill_value with reindex
sales_feb_aligned = sales_feb.reindex(common_index, fill_value=0)
sales_feb_aligned
# Out:
#          Sales
# Store_A    260
# Store_B      0
# Store_C    310

# %%
sales_diff = sales_feb_aligned['Sales'] - sales_jan['Sales']
sales_diff
# Out:
# Store_A     10
# Store_B   -400
# Store_C     10
# Name: Sales, dtype: int64

# %%
sales_feb_new = pd.DataFrame({
    'Sales': [260, 310, 100]
}, index=['Store_A', 'Store_C', 'Store_D'])

sales_feb_new
# Out:
#          Sales
# Store_A    260
# Store_C    310
# Store_D    100

# %%
common_index = list(set(list(sales_jan.index) + list(sales_feb_new.index)))
common_index
# Out:
# ['Store_D', 'Store_B', 'Store_A', 'Store_C']

# %%
sales_jan_aligned = sales_jan.reindex(common_index, fill_value=0)
sales_jan_aligned
# Out:
#          Sales
# Store_D      0
# Store_B    400
# Store_A    250
# Store_C    300

# %%
sales_feb_new_aligned = sales_feb_new.reindex(common_index, fill_value=0)
sales_feb_new_aligned
# Out:
#          Sales
# Store_D    100
# Store_B      0
# Store_A    260
# Store_C    310

# %%
to_check = 'Store_C'
print(sales_feb_new_aligned.loc[to_check])
print(sales_jan_aligned.loc[to_check])
# Out:
# Sales    310
# Name: Store_C, dtype: int64
# Sales    300
# Name: Store_C, dtype: int64

# %% [markdown]
# # For column

# %%
source_a = pd.DataFrame({
    'Product': ['Laptop', 'Tablet', 'Phone'],
    'Price': [1000, 500, 800],
    'Stock': [30, 50, 100]
})
source_a
# Out:
#   Product  Price  Stock
# 0  Laptop   1000     30
# 1  Tablet    500     50
# 2   Phone    800    100

# %%
source_b = pd.DataFrame({
    'Price': [980, 520, 810],
    'Product': ['Laptop', 'Tablet', 'Phone']
})
source_b
# Out:
#    Price Product
# 0    980  Laptop
# 1    520  Tablet
# 2    810   Phone

# %%
aligned_b = source_b.reindex(columns=source_a.columns, fill_value = 0)
aligned_b
# Out:
#   Product  Price  Stock
# 0  Laptop    980      0
# 1  Tablet    520      0
# 2   Phone    810      0

# %% [markdown]
# # iteration in pandas

# %%
df = pd.DataFrame({
    'Name' : ['heartine', 'gagan', 'gavin'],
    'Age' : [25, 20, 23],
    'City' : ['Delhi', 'Mumbai', 'Chennai'],
})
df
# Out:
#        Name  Age     City
# 0  heartine   25    Delhi
# 1     gagan   20   Mumbai
# 2     gavin   23  Chennai

# %%
# df.iterrows()
# slow for large DataFrames
# For performance-critical loops, use itertuples() (faster) or vectorized operations.


for index, row in df.iterrows():
    print(f"{index}: {row['Name']} lives in {row['City']} and is {row['Age']} years old.")
# Out:
# 0: heartine lives in Delhi and is 25 years old.
# 1: gagan lives in Mumbai and is 20 years old.
# 2: gavin lives in Chennai and is 23 years old.

# %%
# df.itertuples()
for row in df.itertuples():
    print(f"{row.Name} lives in {row.City}, and is {row.Age} years old.", end='\n\n')
# Out:
# heartine lives in Delhi, and is 25 years old.
#
# gagan lives in Mumbai, and is 20 years old.
#
# gavin lives in Chennai, and is 23 years old.

# %%
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].values, end='\n\n')
# Out:
# Column: Name
# ['heartine' 'gagan' 'gavin']
#
# Column: Age
# [25 20 23]
#
# Column: City
# ['Delhi' 'Mumbai' 'Chennai']

# %% [markdown]
# # Condition based column creation using custom logic

# %%
df.head()
# Out:
#        Name  Age     City
# 0  heartine   25    Delhi
# 1     gagan   20   Mumbai
# 2     gavin   23  Chennai

# %%
# if age >=30, senior else young

val = []
for row in df.itertuples():
    if row.Age >= 30:
        val.append("Senior")
    else:
        val.append("Junior")


df["Seniority"] = val
df
# Out:
#        Name  Age     City Seniority
# 0  heartine   25    Delhi    Junior
# 1     gagan   20   Mumbai    Junior
# 2     gavin   23  Chennai    Junior

# %% [markdown]
# # vectorized using apply

# %%
df = pd.DataFrame({
    'Name' : ['heartine', 'gagan', 'gavin'],
    'Age' : [25, 20, 23],
    'City' : ['Delhi', 'Mumbai', 'Chennai'],
})
df
# Out:
#        Name  Age     City
# 0  heartine   25    Delhi
# 1     gagan   20   Mumbai
# 2     gavin   23  Chennai

# %%
df['Categories'] = df['Age'].apply(lambda age : 'young' if age < 30 else 'senior')
df
# apply() — Fastest (and most Pythonic)
# not as fast as true NumPy vectorization (but very close)
# iterrows < itertuples < apply
# Out:
#        Name  Age     City Categories
# 0  heartine   25    Delhi      young
# 1     gagan   20   Mumbai      young
# 2     gavin   23  Chennai      young

# %% [markdown]
# # Sort

# %%
# 1. sort_values --> data values
# 2. sort_index --> rows / column

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = pd.read_csv(titanic_dataset_github_url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sorted_df = df.sort_values(by='Age')
sorted_df[['Name', 'Age']].head(100)
# Out:
#                                  Name    Age
# 803   Thomas, Master. Assad Alexander   0.42
# 755         Hamalainen, Master. Viljo   0.67
# 644            Baclini, Miss. Eugenie   0.75
# 469     Baclini, Miss. Helene Barbara   0.75
# 78      Caldwell, Master. Alden Gates   0.83
# ..                                ...    ...
# 220    Sunderland, Mr. Victor Francis  16.00
# 791               Gaskell, Mr. Alfred  16.00
# 86             Ford, Mr. William Neal  16.00
# 71         Goodwin, Miss. Lillian Amy  16.00
# 156  Gilnagh, Miss. Katherine "Katie"  16.00
#
# [100 rows x 2 columns]

# %%
sorted_df.loc[0:100, ['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 289                               Connolly, Miss. Kate  22.0
# 323  Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...  22.0
# 243                      Maenpaa, Mr. Matti Alexanteri  22.0
# 521                                    Vovk, Mr. Janko  22.0
# ..                                                 ...   ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0
# 399                   Trout, Mrs. William H (Jessie L)  28.0
# 392                       Gustafsson, Mr. Johan Birger  28.0
# 635                                  Davis, Miss. Mary  28.0
# 100                            Petranec, Miss. Matilda  28.0
#
# [146 rows x 2 columns]

# %%
print(df['Age'].dtype)
# Out:
# float64

# %%
# df['Age'] = df['Age'].astype('int64')

# convert a column to an integer type (int64) but there are NaN values in it, and integers can't represent NaN.
# Would give an error - IntCastingNaNError

# %%
# astype changes the data type of the coulumn.
df['Age'] = df['Age'].fillna(0).astype('int64')
print(df['Age'].dtype)
# Out:
# int64

# %%
# sort by multiple columns
df_sorted = df.sort_values(by=['Pclass', 'Fare']) # ascending order
# Sorts the DataFrame first by Pclass, then (within each Pclass) by Fare
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 263          264         0       1            Harrison, Mr. William  male
# 633          634         0       1    Parr, Mr. William Henry Marsh  male
# 806          807         0       1           Andrews, Mr. Thomas Jr  male
# 815          816         0       1                 Fry, Mr. Richard  male
# 822          823         0       1  Reuchlin, Jonkheer. John George  male
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 263   40      0      0  112059   0.0   B94        S
# 633    0      0      0  112052   0.0   NaN        S
# 806   39      0      0  112050   0.0   A36        S
# 815    0      0      0  112058   0.0  B102        S
# 822   38      0      0   19972   0.0   NaN        S

# %%
df_sorted = df.sort_values(by=['Pclass', 'Fare'], ascending=[True, False])
# Pclass will be sorted in asc and fare in decending
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 88            89         1       1          Fortune, Miss. Mabel Helen
#
#         Sex  Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female   35      0      0  PC 17755  512.3292          NaN        C
# 679    male   36      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male   35      0      0  PC 17755  512.3292         B101        C
# 27     male   19      3      2     19950  263.0000  C23 C25 C27        S
# 88   female   23      3      2     19950  263.0000  C23 C25 C27        S

# %%
# df_sorted.to_csv("a.csv")

# %% [markdown]
# # sort_index

# %%
df_sort_2 = df.set_index('PassengerId')

# %%
df_sorted_by_index = df_sort_2.sort_index(axis=0)
# axis=0 means you’re sorting rows, based on the row index labels.
df_sorted_by_index.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df_sorted_by_index = df_sort_2.sort_index(axis=0, ascending=False)
df_sorted_by_index.head()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 891                 0       3                       Dooley, Mr. Patrick
# 890                 1       1                     Behr, Mr. Karl Howell
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 888                 1       1              Graham, Miss. Margaret Edith
# 887                 0       2                     Montvila, Rev. Juozas
#
#                 Sex  Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 891            male   32      0      0      370376   7.75   NaN        Q
# 890            male   26      0      0      111369  30.00  C148        C
# 889          female    0      1      2  W./C. 6607  23.45   NaN        S
# 888          female   19      0      0      112053  30.00   B42        S
# 887            male   27      0      0      211536  13.00   NaN        S

# %%
# df_sort_2.sort_index(axis=0, ascending=False,inplace=True)
# axis=0 → Sort rows (default)
# ascending=False → Sort in descending order
# inplace=True → Make the changes directly in df_sort_2 without needing to assign to a new variable

# %% [markdown]
# # sorting columns alphabets

# %%
df_sorted_cols = df.sort_index(axis=1)
# sort_index(axis=1) → Sorts the columns 
# alphabetically by their names (because axis=1 means columns).
df_sorted_cols.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1         0         A/5 21171
# 1       1  female      1         1          PC 17599
# 2       3  female      0         1  STON/O2. 3101282
# 3       1  female      1         1            113803
# 4       3    male      0         0            373450

# %% [markdown]
# # Changing Column order in Pandas

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = pd.read_csv(titanic_dataset_github_url)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new_order = ['Name', 'Sex', 'Age', 'Pclass', 'Fare', 'Survived']
df_reordered = df[new_order]
print(df_reordered.head())
# Out:
#                                                 Name     Sex   Age  Pclass  \
# 0                            Braund, Mr. Owen Harris    male  22.0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                             Heikkinen, Miss. Laina  female  26.0       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                           Allen, Mr. William Henry    male  35.0       3
#
#       Fare  Survived
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         1
# 3  53.1000         1
# 4   8.0500         0

# %%
sorted(df.columns)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'Ticket']

# %%
df_reordered = df[sorted(df.columns)]
df_reordered.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1         0         A/5 21171
# 1       1  female      1         1          PC 17599
# 2       3  female      0         1  STON/O2. 3101282
# 3       1  female      1         1            113803
# 4       3    male      0         0            373450

# %% [markdown]
# # working with text data in pandas

# %%
print(df[['Name', 'Sex', 'Cabin']].head(3))
# Out:
#                                                 Name     Sex Cabin
# 0                            Braund, Mr. Owen Harris    male   NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                             Heikkinen, Miss. Laina  female   NaN

# %%
df['Name'].str.lower()
# df['Name'].str.upper()
# df['Name'].str.capitalize()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
df['Name'].str.replace("Mr.", "Sir", regex=False).head()
# regular expressions (regex) regex=False tells Pandas to treat "Mr." as a literal string, not a regular expression
# If you forget regex=False, Pandas might misinterpret "." as "any character"
# it could match "MrX", "Mra", "Mr " 
# because "." is a regex wildcard.
# Out:
# 0                              Braund, Sir Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Sir William Henry
# Name: Name, dtype: object

# %%
df['Name'].str.replace(r"\(.*\)", "", regex=True).head()
# r"\(.*\)"
# Part	        Meaning
# r"..."	Raw string (so \ is not interpreted by Python)
# \(	Matches a literal opening parenthesis (
# .*	Matches any characters (except newlines), zero or more times
# \)	Matches a literal closing parenthesis )
# So \(.*\) matches: " (Mr.)" / " (CEO)" / " (Head of HR)"
# r"\s*\(.*\)"	Also removes spaces before ()
# Out:
# 0          Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley
# 2           Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath
# 4         Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df['Title'] = df['Name'].str.extract(r'(\(.*\))', expand=False)
# expand=False returns a Series instead of a DataFrame (simpler for one column).
df['Title']
# Out:
# 0                           NaN
# 1      (Florence Briggs Thayer)
# 2                           NaN
# 3               (Lily May Peel)
# 4                           NaN
#                  ...
# 886                         NaN
# 887                         NaN
# 888                         NaN
# 889                         NaN
# 890                         NaN
# Name: Title, Length: 891, dtype: object

# %% [markdown]
# # Split and Access Elements

# %%
df['Name'].str.split(",", expand=True)[0]
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: 0, Length: 891, dtype: object

# %%
df['Name'].str.strip() 
# df['Name'].str.lstrip()
# df['Name'].str.rstrip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# # Find position of substring

# %%
df['Name'].str.find("Mr")
# Out:
# 0       8
# 1       9
# 2      -1
# 3      10
# 4       7
#        ..
# 886    -1
# 887    -1
# 888    -1
# 889     6
# 890     8
# Name: Name, Length: 891, dtype: int64

# %%
# Count passengers with “Miss” in name
count = df['Name'].str.contains("Miss").sum()
print("Number of 'Miss':", count)
# Out:
# Number of 'Miss': 182

# %%
df = pd.read_csv(titanic_dataset_github_url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data = {
    'Name' : [
        'Monal K', 'Bhuvika', 'Niranjan', 'riyan'
    ],
    'Email' : [
        'm@gmail.com', 'b@gmail.com', 'n@gmail.com', 'r@gmail.com'
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#        Name        Email
# 0   Monal K  m@gmail.com
# 1   Bhuvika  b@gmail.com
# 2  Niranjan  n@gmail.com
# 3     riyan  r@gmail.com

# %%
df['Name'].str.replace("K", "Kumar", regex=False)
# Out:
# 0    Monal Kumar
# 1        Bhuvika
# 2       Niranjan
# 3          riyan
# Name: Name, dtype: object

# %%
df['Name'].str.pad(width=20, side='left', fillchar='-')
# df['Name'].str.pad(width=20, side='right', fillchar='-')
# Out:
# 0    -------------Monal K
# 1    -------------Bhuvika
# 2    ------------Niranjan
# 3    ---------------riyan
# Name: Name, dtype: object

# %% [markdown]
# # Options and customizations

# %%
df = pd.read_csv(titanic_dataset_github_url)

# %%
pd.set_option('display.max_rows', 3)
df
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male  22.0
# ..           ...       ...     ...                      ...   ...   ...
# 890          891         0       3      Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 0        1      0  A/5 21171  7.25   NaN        S
# ..     ...    ...        ...   ...   ...      ...
# 890      0      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_columns', None)
# display all columns when printing a DataFrame — instead of truncating them with ... when there are too many.
# pd.reset_option('display.max_columns') # to reset
df
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male  22.0
# ..           ...       ...     ...                      ...   ...   ...
# 890          891         0       3      Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 0        1      0  A/5 21171  7.25   NaN        S
# ..     ...    ...        ...   ...   ...      ...
# 890      0      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_rows', 30)
df[['Fare', 'Age']].head() # because of head only 5 rows displayed
# Out:
#       Fare   Age
# 0   7.2500  22.0
# 1  71.2833  38.0
# 2   7.9250  26.0
# 3  53.1000  35.0
# 4   8.0500  35.0

# %%
# Check Current Value of an Option
pd.get_option('display.max_rows')
# Out:
# 30

# %%
# Temporarily Set Option (Context Manager)
with pd.option_context('display.max_rows', 3):
    print(df)
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male  22.0
# ..           ...       ...     ...                      ...   ...   ...
# 890          891         0       3      Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 0        1      0  A/5 21171  7.25   NaN        S
# ..     ...    ...        ...   ...   ...      ...
# 890      0      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.reset_option('display.max_rows') # Resetting to Default
pd.get_option('display.max_rows')
# Out:
# 60

# %%
# You can also reset all options:
pd.reset_option('all') # it will throw an error / Warning
# Out:
# C:\Users\nikunj.dhaka\AppData\Local\Temp\ipykernel_18376\1157646725.py:2: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all') # it will throw an error / Warning
# C:\Users\nikunj.dhaka\AppData\Local\Temp\ipykernel_18376\1157646725.py:2: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all') # it will throw an error / Warning
# Matplotlib is building the font cache; this may take a moment.

# %%
import warnings


with warnings.catch_warnings():
    warnings.simplefilter('ignore', FutureWarning)
    pd.reset_option('all')

# %%
import matplotlib

# %% [markdown]
# # Categorical Data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df['Sex'].dtype)
# Out:
# object

# %%
# Convert a column to categorical
# pandas Categorical type, - new column called 'Sex_C'
# which is more memory- and performance-efficient.
df['Sex_C'] = df['Sex'].astype('category')
df[['Sex', 'Sex_C']].head()
# Out:
#       Sex   Sex_C
# 0    male    male
# 1  female  female
# 2  female  female
# 3  female  female
# 4    male    male

# %%
print(df['Sex'].dtype)
print(df['Sex_C'].dtype)
# Out:
# object
# category

# %%
df['Sex_C_categorical_codes'] = df['Sex_C'].cat.codes
df[['Sex', 'Sex_C', , 'Sex_C_categorical_codes']].head()
# Out:
#       Sex   Sex_C  Sex_C_categorical_codes
# 0    male    male                        1
# 1  female  female                        0
# 2  female  female                        0
# 3  female  female                        0
# 4    male    male                        1

# %%
df['Sex_apply_category'] = df['Sex'].apply(lambda x : 0 if x == 'male' else 1)
# creates a new column Sex_apply_category in a pandas DataFrame df 
# by applying a lambda function to the Sex column

# %%
df[['Sex', 'Sex_C', 'Sex_C_categorical_codes', 'Sex_apply_category']].head()
# Out:
#       Sex   Sex_C  Sex_C_categorical_codes  Sex_apply_category
# 0    male    male                        1                   0
# 1  female  female                        0                   1
# 2  female  female                        0                   1
# 3  female  female                        0                   1
# 4    male    male                        1                   0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Sex_C  \
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male
#
#    Sex_C_categorical_codes  Sex_apply_category
# 0                        1                   0
# 1                        0                   1
# 2                        0                   1
# 3                        0                   1
# 4                        1                   0

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass_new_weird'] = df['Pclass'].apply(lambda x : 'adf' if x == 3 else ('wer' if x == 2 else 'tyu'))
df[['Pclass', 'Pclass_new_weird']].head(10)
# Out:
#    Pclass Pclass_new_weird
# 0       3              adf
# 1       1              tyu
# 2       3              adf
# 3       1              tyu
# 4       3              adf
# 5       3              adf
# 6       1              tyu
# 7       3              adf
# 8       3              adf
# 9       2              wer

# %%
print(df['Pclass'].dtype)
print(df['Pclass_new_weird'].dtype)
# Out:
# int64
# object

# %%
df['Pclass_new_weird_ordered'] = pd.Categorical(
    df['Pclass_new_weird'],
    categories=['wer','adf', 'tyu'], # Custom order (ascending)
    ordered=True
)

print(df['Pclass_new_weird_ordered'].dtype)

# pandas.Categorical to convert a column into an ordered categorical type with a custom order of categories
# Converts df['Pclass_new_weird'] into a categorical variable with a specific order: 
# 'wer' < 'adf' < 'tyu'.
# ordered=True flag makes comparison operators like <, > meaningful
# Any value not in that list becomes NaN.
# Out:
# category

# %%
df['Pclass_new_weird_ordered'].cat.categories
# Out:
# Index(['wer', 'adf', 'tyu'], dtype='object')

# %%
df['Pclass_new_weird_ordered'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Date Functionality in pandas

# %%
df = pd.DataFrame({
    'event': ['Concert', 'Conference', 'Wedding', 'Reception', 'last_day'],
    'date': ['2025-01-01', '2025-03-15', '2025-07-20', '2025-07-21', '2025-07-31']
})
df
# Out:
#         event        date
# 0     Concert  2025-01-01
# 1  Conference  2025-03-15
# 2     Wedding  2025-07-20
# 3   Reception  2025-07-21
# 4    last_day  2025-07-31

# %%
df['date_pandas'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         event        date date_pandas
# 0     Concert  2025-01-01  2025-01-01
# 1  Conference  2025-03-15  2025-03-15
# 2     Wedding  2025-07-20  2025-07-20
# 3   Reception  2025-07-21  2025-07-21
# 4    last_day  2025-07-31  2025-07-31

# %%
print(df.dtypes[['event', 'date', 'date_pandas']])
# Out:
# event                  object
# date                   object
# date_pandas    datetime64[ns]
# dtype: object

# %%
df = df.drop('date', axis=1) # will drop the series named "date"
df
# Out:
#         event date_pandas
# 0     Concert  2025-01-01
# 1  Conference  2025-03-15
# 2     Wedding  2025-07-20
# 3   Reception  2025-07-21
# 4    last_day  2025-07-31

# %%
# df['date_pandas'].dt.year
df['date_pandas'].dt.month
# Out:
# 0    1
# 1    3
# 2    7
# 3    7
# 4    7
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day
# Out:
# 0     1
# 1    15
# 2    20
# 3    21
# 4    31
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.weekday
# Out:
# 0    2
# 1    5
# 2    6
# 3    0
# 4    3
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day_name()
# Out:
# 0    Wednesday
# 1     Saturday
# 2       Sunday
# 3       Monday
# 4     Thursday
# Name: date_pandas, dtype: object

# %%
df['date_pandas'].dt.is_month_end
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: date_pandas, dtype: bool

# %%
df[df['date_pandas'] > '2025-04-01']
# Out:
#        event date_pandas
# 2    Wedding  2025-07-20
# 3  Reception  2025-07-21
# 4   last_day  2025-07-31

# %%
df[df['date_pandas'].between('2025-01-01', '2025-06-01')]
# Out:
#         event date_pandas
# 0     Concert  2025-01-01
# 1  Conference  2025-03-15

# %% [markdown]
# # Date range

# %%
pd.date_range(start='2024-01-01', end='2024-01-10', freq='D')
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2024-01-01', end='2024-03-10', freq='ME') # Month end
# Out:
# DatetimeIndex(['2024-01-31', '2024-02-29'], dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range(start='2024-01-01', end='2024-03-10', freq='MS')
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01'], dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# # Date Arithmetic

# %%
df['next_week'] = df['date_pandas'] + pd.Timedelta(days=7)
df[['date_pandas', 'next_week']]
# Out:
#   date_pandas  next_week
# 0  2025-01-01 2025-01-08
# 1  2025-03-15 2025-03-22
# 2  2025-07-20 2025-07-27
# 3  2025-07-21 2025-07-28
# 4  2025-07-31 2025-08-07

# %%
df['days_to_event'] = df['date_pandas'] - pd.Timestamp.today()
df.head()
# Out:
#         event date_pandas  next_week              days_to_event
# 0     Concert  2025-01-01 2025-01-08 -190 days +07:50:10.836513
# 1  Conference  2025-03-15 2025-03-22 -117 days +07:50:10.836513
# 2     Wedding  2025-07-20 2025-07-27    10 days 07:50:10.836513
# 3   Reception  2025-07-21 2025-07-28    11 days 07:50:10.836513
# 4    last_day  2025-07-31 2025-08-07    21 days 07:50:10.836513

# %%
# Assignment - 1

# TODO - While creating a task, ask user about the deadline

# Start date - Pick automatically from today's date
# Deadline - 7, 10, 10

# # to-DO

# 1. Task-1 | Days left  | Green-color
# 2. Task-2 | Days left  | Red-color
# 3. Task-3 | Days left  | Green-color
# 4. Task-4 | Days left  | Red-color
